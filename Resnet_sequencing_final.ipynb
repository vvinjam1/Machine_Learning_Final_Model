# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import librosa
import glob
import json
import pickle
import shutil

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks, regularizers
from tensorflow.keras.utils import register_keras_serializable

tf.get_logger().setLevel('ERROR')

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

np.random.seed(42)
tf.random.set_seed(42)

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"GPU Available: {gpus[0].name}")
else:
    print("No GPU detected - using CPU")

print("Completed setup")
# Out:
# GPU Available: /physical_device:GPU:0
# Completed setup

# %%
import kagglehub
path = kagglehub.dataset_download("yashdogra/speech-commands")
print(f"Path to dataset files: {path}")
# Out:
# Using Colab cache for faster access to the 'speech-commands' dataset.
# Path to dataset files: /kaggle/input/speech-commands

# %%
if os.path.exists(path):
    contents = os.listdir(path)
    print(f"Dataset found at: {path}")
    print(f"Total folders: {len(contents)}")
    print(f"Sample folders: {contents[:5]}...")
else:
    print(f"Dataset NOT found at: {path}")

COMMANDS = [
    'yes', 'no', 'up', 'down', 'left', 'right',
    'on', 'off', 'stop', 'go'
]

SAMPLE_RATE    = 16000
AUDIO_LENGTH   = 16000
N_MELS         = 128
N_FFT          = 2048
HOP_LENGTH     = 160
MAX_SAMPLES    = None

NOISE_AUGMENT_PROB = 0.4
NOISE_SNR_DB       = 10

MAX_OUTPUT_LEN  = 2
N_SEQ_TRAIN     = 8000
N_SEQ_VAL       = 1500
N_SEQ_TEST      = 1500
SEQ_SILENCE_MS  = 200
MODEL_NAME      = 'resnet_sequencing'

print(f"Commands: {COMMANDS}")
print(f"Expected spectrogram shape: ({N_MELS}, {AUDIO_LENGTH // HOP_LENGTH + 1})")
print(f"Model name: {MODEL_NAME}")
# Out:
# Dataset found at: /kaggle/input/speech-commands
# Total folders: 40
# Sample folders: ['no', 'two', 'backward', 'four', 'five']...
# Commands: ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go']
# Expected spectrogram shape: (128, 101)
# Model name: resnet_sequencing

# %% [markdown]
# # Preprocessing Pipeline

# %%
def load_audio(file_path, target_sr=SAMPLE_RATE):
    audio, sr = librosa.load(file_path, sr=target_sr)
    return audio, sr

def pad_or_trim(audio, target_length=AUDIO_LENGTH):
    if len(audio) < target_length:
        audio = np.pad(audio, (0, target_length - len(audio)), mode='constant')
    else:
        audio = audio[:target_length]
    return audio

def normalize_audio(audio):
    max_val = np.max(np.abs(audio))
    if max_val > 0:
        audio = audio / max_val
    return audio

def preprocess_audio(file_path, target_sr=SAMPLE_RATE, target_length=AUDIO_LENGTH):
    audio, sr = load_audio(file_path, target_sr)
    audio = pad_or_trim(audio, target_length)
    audio = normalize_audio(audio)
    return audio

def extract_mel_spectrogram(audio, sr=SAMPLE_RATE, n_mels=N_MELS,
                             n_fft=N_FFT, hop_length=HOP_LENGTH):
    mel_spec = librosa.feature.melspectrogram(
        y=audio, sr=sr, n_mels=n_mels, n_fft=n_fft, hop_length=hop_length
    )
    return librosa.power_to_db(mel_spec, ref=np.max)

NOISE_PATH = os.path.join(path, '_background_noise_')

def load_noise_files(noise_path, target_sr=SAMPLE_RATE):
    noise_clips = []
    for f in glob.glob(os.path.join(noise_path, '*.wav')):
        audio, _ = librosa.load(f, sr=target_sr)
        noise_clips.append(audio)
    print(f"Loaded {len(noise_clips)} noise files")
    return noise_clips

def create_noise_samples(noise_clips, target_length=AUDIO_LENGTH, n_samples=1500):
    samples = []
    for _ in range(n_samples):
        clip  = noise_clips[np.random.randint(len(noise_clips))]
        if len(clip) < target_length:
            clip = np.pad(clip, (0, target_length - len(clip)))
        start = np.random.randint(0, len(clip) - target_length)
        samples.append(clip[start:start + target_length])
    return samples

def mix_noise(audio, noise_clips, snr_db=NOISE_SNR_DB):
    noise = noise_clips[np.random.randint(len(noise_clips))]
    if len(noise) < len(audio):
        noise = np.pad(noise, (0, len(audio) - len(noise)))
    start = np.random.randint(0, len(noise) - len(audio) + 1)
    noise = noise[start:start + len(audio)]
    signal_power = np.mean(audio ** 2) + 1e-9
    noise_power  = np.mean(noise  ** 2) + 1e-9
    scale = np.sqrt(signal_power / (noise_power * (10 ** (snr_db / 10))))
    return normalize_audio(audio + scale * noise)

noise_clips   = load_noise_files(NOISE_PATH)
noise_samples = create_noise_samples(noise_clips, n_samples=1500)
print(f"Created {len(noise_samples)} noise samples")
print(f"Expected spectrogram shape: ({N_MELS}, {AUDIO_LENGTH // HOP_LENGTH + 1})")
# Out:
# Loaded 6 noise files
# Created 1500 noise samples
# Expected spectrogram shape: (128, 101)

# %%
class SpecAugment:
    def __init__(self, freq_mask_param=15, time_mask_param=10,
                 num_freq_masks=1, num_time_masks=1):
        self.freq_mask_param = freq_mask_param
        self.time_mask_param = time_mask_param
        self.num_freq_masks  = num_freq_masks
        self.num_time_masks  = num_time_masks

    def frequency_mask(self, spec):
        num_mels = spec.shape[0]
        for _ in range(self.num_freq_masks):
            f  = min(np.random.randint(0, self.freq_mask_param + 1), num_mels)
            f0 = np.random.randint(0, max(1, num_mels - f))
            spec[f0:f0 + f, :] = spec.mean()
        return spec

    def time_mask(self, spec):
        num_frames = spec.shape[1]
        for _ in range(self.num_time_masks):
            t  = min(np.random.randint(0, self.time_mask_param + 1), num_frames)
            t0 = np.random.randint(0, max(1, num_frames - t))
            spec[:, t0:t0 + t] = spec.mean()
        return spec

    def __call__(self, spec, augment_prob=0.5):
        if np.random.random() > augment_prob:
            return spec
        spec = spec.copy()
        spec = self.frequency_mask(spec)
        spec = self.time_mask(spec)
        return spec

spec_augment = SpecAugment(
    freq_mask_param=15, time_mask_param=10,
    num_freq_masks=1,   num_time_masks=1
)
print(f"Frequency mask: up to {spec_augment.freq_mask_param} bands")
print(f"Time mask: up to {spec_augment.time_mask_param} frames")
# Out:
# Frequency mask: up to 15 bands
# Time mask: up to 10 frames

# %%
def create_dataset(dataset_path, commands, noise_samples=None,
                   max_samples_per_class=None, verbose=True):
    X_raw, X, y = [], [], []
    print("LOADING DATASET")

    for command in commands:
        command_path = os.path.join(dataset_path, command)
        if not os.path.exists(command_path):
            print(f"Warning: Folder not found for '{command}'")
            continue
        files = [f for f in os.listdir(command_path) if f.endswith('.wav')]
        if max_samples_per_class:
            files = files[:max_samples_per_class]
        if verbose:
            print(f"  Processing '{command}': {len(files)} files")
        for file_name in files:
            try:
                audio    = preprocess_audio(os.path.join(command_path, file_name))
                features = extract_mel_spectrogram(audio)
                X_raw.append(audio)
                X.append(features)
                y.append(command)
            except Exception:
                continue

    if noise_samples is not None:
        print(f"  Processing '_background_noise_': {len(noise_samples)} samples")
        for audio in noise_samples:
            audio    = normalize_audio(audio)
            features = extract_mel_spectrogram(audio)
            X_raw.append(audio)
            X.append(features)
            y.append('_background_noise_')

    X_raw = np.array(X_raw)
    X     = np.array(X)
    y     = np.array(y)

    print(f"Dataset created: {len(X)} samples, {len(np.unique(y))} classes")
    print(f"Feature shape: {X.shape}")
    return X_raw, X, y

X_raw, X, y = create_dataset(
    path, COMMANDS,
    noise_samples=noise_samples,
    max_samples_per_class=MAX_SAMPLES
)
# Out:
# LOADING DATASET
#   Processing 'yes': 4044 files
#   Processing 'no': 3941 files
#   Processing 'up': 3723 files
#   Processing 'down': 3917 files
#   Processing 'left': 3801 files
#   Processing 'right': 3778 files
#   Processing 'on': 3845 files
#   Processing 'off': 3745 files
#   Processing 'stop': 3872 files
#   Processing 'go': 3880 files
#   Processing '_background_noise_': 1500 samples
# Dataset created: 40046 samples, 11 classes
# Feature shape: (40046, 128, 101)

# %%
print("PREPARING DATA")

label_encoder = LabelEncoder()
y_encoded     = label_encoder.fit_transform(y)
num_classes   = len(label_encoder.classes_)

print(f"Label encoding:")
for i, label in enumerate(label_encoder.classes_):
    print(f"  {i}: '{label}'")

X_train, X_test, X_raw_train, X_raw_test, y_train, y_test = train_test_split(
    X, X_raw, y_encoded, test_size=0.15, random_state=42, stratify=y_encoded)
X_train, X_val, X_raw_train, X_raw_val, y_train, y_val = train_test_split(
    X_train, X_raw_train, y_train, test_size=0.12, random_state=42, stratify=y_train)

print(f"\nDataset split:")
print(f"  Training:   {X_train.shape[0]:,} ({X_train.shape[0]/len(X)*100:.1f}%)")
print(f"  Validation: {X_val.shape[0]:,} ({X_val.shape[0]/len(X)*100:.1f}%)")
print(f"  Test:       {X_test.shape[0]:,} ({X_test.shape[0]/len(X)*100:.1f}%)")

X_train = X_train[..., np.newaxis]
X_val   = X_val[..., np.newaxis]
X_test  = X_test[..., np.newaxis]

X_mean = float(np.mean(X_train))
X_std  = float(np.std(X_train))
X_train = (X_train - X_mean) / X_std
X_val   = (X_val   - X_mean) / X_std
X_test  = (X_test  - X_mean) / X_std

print(f"Input shape: {X_train.shape[1:]}")
print(f"Normalization: mean={X_mean:.4f}, std={X_std:.4f}")
# Out:
# PREPARING DATA
# Label encoding:
#   0: '_background_noise_'
#   1: 'down'
#   2: 'go'
#   3: 'left'
#   4: 'no'
#   5: 'off'
#   6: 'on'
#   7: 'right'
#   8: 'stop'
#   9: 'up'
#   10: 'yes'
#
# Dataset split:
#   Training:   29,954 (74.8%)
#   Validation: 4,085 (10.2%)
#   Test:       6,007 (15.0%)
# Input shape: (128, 101, 1)
# Normalization: mean=-56.7310, std=20.2851

# %%
def create_sequential_dataset(X_raw, y, n_samples, max_commands=2,
                               silence_ms=SEQ_SILENCE_MS, sr=SAMPLE_RATE):
    silence = np.zeros(int(sr * silence_ms / 1000))
    X_seq, y_seq = [], []
    for _ in range(n_samples):
        indices = np.random.randint(0, len(X_raw), size=max_commands)
        parts, labels = [], []
        for idx in indices:
            parts.append(X_raw[idx])
            parts.append(silence)
            labels.append(y[idx])
        combined = normalize_audio(np.concatenate(parts))
        X_seq.append(combined)
        y_seq.append(labels)
    return X_seq, np.array(y_seq)

print("Creating sequential datasets...")
X_seq_train, y_seq_train = create_sequential_dataset(X_raw_train, y_train, N_SEQ_TRAIN)
X_seq_val,   y_seq_val   = create_sequential_dataset(X_raw_val,   y_val,   N_SEQ_VAL)
X_seq_test,  y_seq_test  = create_sequential_dataset(X_raw_test,  y_test,  N_SEQ_TEST)

sample_specs = np.array([extract_mel_spectrogram(X_seq_train[i])
                          for i in range(min(500, len(X_seq_train)))])
X_seq_mean = float(np.mean(sample_specs))
X_seq_std  = float(np.std(sample_specs))

print(f"  Train: {len(X_seq_train)}  Val: {len(X_seq_val)}  Test: {len(X_seq_test)}")
print(f"  Seq normalization: mean={X_seq_mean:.4f}, std={X_seq_std:.4f}")
print(f"  Sequence length: ~{len(X_seq_train[0])/SAMPLE_RATE:.1f}s")
# Out:
# Creating sequential datasets...
#   Train: 8000  Val: 1500  Test: 1500
#   Seq normalization: mean=-61.6768, std=19.5480
#   Sequence length: ~2.4s

# %%
@register_keras_serializable(package="CustomSchedules")
class CosineDecayWithWarmup(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, initial_learning_rate=1e-3, decay_steps=10000,
                 warmup_steps=1000, min_learning_rate=1e-6):
        super().__init__()
        self.initial_learning_rate = initial_learning_rate
        self.decay_steps           = decay_steps
        self.warmup_steps          = warmup_steps
        self.min_learning_rate     = min_learning_rate

    def __call__(self, step):
        step     = tf.cast(step, tf.float32)
        warmup_f = tf.cast(self.warmup_steps, tf.float32)
        decay_f  = tf.cast(self.decay_steps,  tf.float32)
        warmup_lr   = self.initial_learning_rate * (step / tf.maximum(warmup_f, 1.0))
        decay_step  = step - warmup_f
        total_decay = tf.maximum(decay_f - warmup_f, 1.0)
        cosine      = 0.5 * (1.0 + tf.cos(np.pi * decay_step / total_decay))
        decayed_lr  = self.min_learning_rate + \
                      (self.initial_learning_rate - self.min_learning_rate) * cosine
        return tf.where(step < warmup_f, warmup_lr, decayed_lr)

    def get_config(self):
        return {
            'initial_learning_rate': float(self.initial_learning_rate),
            'decay_steps':           int(self.decay_steps),
            'warmup_steps':          int(self.warmup_steps),
            'min_learning_rate':     float(self.min_learning_rate)
        }

    @classmethod
    def from_config(cls, config):
        return cls(**config)

print("CosineDecayWithWarmup defined")
# Out:
# CosineDecayWithWarmup defined

# %%
# ── Part 1: Precompute all spectrograms once ──────────────────
print("Precomputing single-command spectrograms...")
X_spec_train = np.array([extract_mel_spectrogram(a) for a in X_raw_train])
X_spec_train = (X_spec_train - X_mean) / X_std

X_spec_val = np.array([extract_mel_spectrogram(a) for a in X_raw_val])
X_spec_val = (X_spec_val - X_mean) / X_std

print("Precomputing sequential spectrograms...")
X_seq_spec_train = np.array([extract_mel_spectrogram(a) for a in X_seq_train])
X_seq_spec_train = (X_seq_spec_train - X_seq_mean) / X_seq_std

X_seq_spec_val = np.array([extract_mel_spectrogram(a) for a in X_seq_val])
X_seq_spec_val = (X_seq_spec_val - X_seq_mean) / X_seq_std

print(f"  Single train: {X_spec_train.shape}")
print(f"  Single val:   {X_spec_val.shape}")
print(f"  Seq train:    {X_seq_spec_train.shape}")
print(f"  Seq val:      {X_seq_spec_val.shape}")

# ── Part 2: Generator class ───────────────────────────────────
class CombinedCommandGenerator(keras.utils.Sequence):
    def __init__(self, X_spec_single, y_single, X_spec_seq, y_seq,
                 batch_size=32, shuffle=True, augment=True,
                 spec_augment=None, noise_clips=None,
                 X_raw_single=None, X_raw_seq=None,
                 single_mean=0, single_std=1,
                 seq_mean=0,    seq_std=1,
                 noise_prob=0.4, augment_prob=0.5, single_ratio=0.5):
        self.X_spec_single = X_spec_single
        self.y_single      = y_single
        self.X_spec_seq    = X_spec_seq
        self.y_seq         = y_seq
        self.X_raw_single  = X_raw_single
        self.X_raw_seq     = X_raw_seq
        self.batch_size    = batch_size
        self.shuffle       = shuffle
        self.augment       = augment
        self.spec_augment  = spec_augment or SpecAugment()
        self.noise_clips   = noise_clips
        self.noise_prob    = noise_prob
        self.single_mean   = single_mean
        self.single_std    = single_std
        self.seq_mean      = seq_mean
        self.seq_std       = seq_std
        self.augment_prob  = augment_prob
        self.n_single      = max(1, int(batch_size * single_ratio))
        self.n_seq         = batch_size - self.n_single
        self.single_idx    = np.arange(len(X_spec_single))
        self.seq_idx       = np.arange(len(X_spec_seq))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.X_spec_seq) / self.n_seq))

    def _augment_spec(self, spec):
        if self.augment:
            spec = self.spec_augment(spec.copy(), augment_prob=self.augment_prob)
        return spec

    def _maybe_add_noise(self, spec, raw_audio, mean, std):
        if (self.augment and self.noise_clips is not None
                and raw_audio is not None
                and np.random.random() < self.noise_prob):
            noisy = mix_noise(raw_audio, self.noise_clips)
            spec  = extract_mel_spectrogram(noisy)
            spec  = (spec - mean) / std
        return self._augment_spec(spec)

    def __getitem__(self, idx):
        s_idx   = self.single_idx[
            np.random.randint(0, len(self.single_idx), self.n_single)
        ]
        q_start = idx * self.n_seq
        q_end   = min(q_start + self.n_seq, len(self.X_spec_seq))
        q_idx   = self.seq_idx[q_start:q_end]

        single_specs = []
        for i in s_idx:
            raw  = self.X_raw_single[i] if self.X_raw_single is not None else None
            spec = self._maybe_add_noise(
                self.X_spec_single[i], raw, self.single_mean, self.single_std)
            single_specs.append(spec)

        seq_specs = []
        for i in q_idx:
            raw  = self.X_raw_seq[i] if self.X_raw_seq is not None else None
            spec = self._maybe_add_noise(
                self.X_spec_seq[i], raw, self.seq_mean, self.seq_std)
            seq_specs.append(spec)

        all_specs = single_specs + seq_specs
        max_T     = max(s.shape[1] for s in all_specs)
        padded    = np.array([
            np.pad(s, ((0, 0), (0, max_T - s.shape[1]))) for s in all_specs
        ])[..., np.newaxis]

        bsz          = len(s_idx) + len(q_idx)
        y_single_out = np.full(bsz, -1, dtype=np.int32)
        y_cmd1       = np.full(bsz, -1, dtype=np.int32)
        y_cmd2       = np.full(bsz, -1, dtype=np.int32)

        for i, si in enumerate(s_idx):
            y_single_out[i] = self.y_single[si]
        for i, qi in enumerate(q_idx):
            y_cmd1[len(s_idx) + i] = self.y_seq[qi, 0]
            y_cmd2[len(s_idx) + i] = self.y_seq[qi, 1]

        return padded, {'single_command': y_single_out,
                        'command_1':      y_cmd1,
                        'command_2':      y_cmd2}

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.single_idx)
            np.random.shuffle(self.seq_idx)


# ── Part 3: Instantiate generators ───────────────────────────
train_generator = CombinedCommandGenerator(
    X_spec_train, y_train, X_seq_spec_train, y_seq_train,
    batch_size=32, shuffle=True, augment=True,
    spec_augment=spec_augment,
    noise_clips=noise_clips,
    X_raw_single=X_raw_train,
    X_raw_seq=X_seq_train,
    single_mean=X_mean,  single_std=X_std,
    seq_mean=X_seq_mean, seq_std=X_seq_std,
    noise_prob=NOISE_AUGMENT_PROB,
    augment_prob=0.5, single_ratio=0.5
)

val_generator = CombinedCommandGenerator(
    X_spec_val, y_val, X_seq_spec_val, y_seq_val,
    batch_size=32, shuffle=False, augment=False,
    single_mean=X_mean,  single_std=X_std,
    seq_mean=X_seq_mean, seq_std=X_seq_std,
)

print(f"✓ Generators ready")
print(f"  Training batches:   {len(train_generator)}")
print(f"  Validation batches: {len(val_generator)}")
# Out:
# Precomputing single-command spectrograms...
# Precomputing sequential spectrograms...
#   Single train: (29954, 128, 101)
#   Single val:   (4085, 128, 101)
#   Seq train:    (8000, 128, 241)
#   Seq val:      (1500, 128, 241)
# ✓ Generators ready
#   Training batches:   500
#   Validation batches: 94

# %%
def residual_block(x, filters, kernel_size=3, stride=1, use_projection=False):
    shortcut = x
    x = layers.Conv2D(filters, kernel_size, strides=stride, padding='same',
                      kernel_initializer='he_normal',
                      kernel_regularizer=keras.regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters, kernel_size, strides=1, padding='same',
                      kernel_initializer='he_normal',
                      kernel_regularizer=keras.regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    if use_projection or stride != 1:
        shortcut = layers.Conv2D(filters, 1, strides=stride, padding='same',
                                 kernel_initializer='he_normal',
                                 kernel_regularizer=keras.regularizers.l2(1e-4))(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)
    x = layers.Add()([x, shortcut])
    return layers.ReLU()(x)

def squeeze_excitation_block(x, ratio=16):
    channels = x.shape[-1]
    se = layers.GlobalAveragePooling2D()(x)
    se = layers.Dense(channels // ratio, activation='relu')(se)
    se = layers.Dense(channels, activation='sigmoid')(se)
    se = layers.Reshape((1, 1, channels))(se)
    return layers.Multiply()([x, se])

def create_resnet_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)

    # ── Stem ──────────────────────────────────────────────────
    x = layers.Conv2D(32, 7, strides=2, padding='same',
                      kernel_initializer='he_normal',
                      kernel_regularizer=keras.regularizers.l2(1e-4))(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling2D(3, strides=2, padding='same')(x)

    # ── Residual stages ───────────────────────────────────────
    x = residual_block(x, 64, use_projection=True)
    x = residual_block(x, 64)
    x = layers.Dropout(0.1)(x)

    x = residual_block(x, 128, stride=2, use_projection=True)
    x = residual_block(x, 128)
    x = layers.Dropout(0.2)(x)

    x = residual_block(x, 256, stride=2, use_projection=True)
    x = residual_block(x, 256)
    x = squeeze_excitation_block(x)
    x = layers.Dropout(0.25)(x)

    x = residual_block(x, 512, stride=2, use_projection=True)
    x = residual_block(x, 512)
    x = squeeze_excitation_block(x)
    x = layers.Dropout(0.3)(x)

    # ── Shared feature vector ──────────────────────────────────
    # GlobalAveragePooling collapses spatial dims to single vector
    # This is shared across all three heads
    shared = layers.GlobalAveragePooling2D()(x)

    # ── Head 1: single command ─────────────────────────────────
    single = layers.Dense(256, activation='relu',
                          kernel_regularizer=keras.regularizers.l2(1e-4))(shared)
    single = layers.BatchNormalization()(single)
    single = layers.Dropout(0.5)(single)
    single = layers.Dense(128, activation='relu',
                          kernel_regularizer=keras.regularizers.l2(1e-4))(single)
    single = layers.BatchNormalization()(single)
    single = layers.Dropout(0.3)(single)
    out_single = layers.Dense(num_classes, activation='softmax',
                              name='single_command')(single)

    # ── Head 2: command 1 of sequence ─────────────────────────
    cmd1 = layers.Dense(256, activation='relu',
                        kernel_regularizer=keras.regularizers.l2(1e-4))(shared)
    cmd1 = layers.BatchNormalization()(cmd1)
    cmd1 = layers.Dropout(0.5)(cmd1)
    cmd1 = layers.Dense(128, activation='relu',
                        kernel_regularizer=keras.regularizers.l2(1e-4))(cmd1)
    cmd1 = layers.BatchNormalization()(cmd1)
    cmd1 = layers.Dropout(0.3)(cmd1)
    out_cmd1 = layers.Dense(num_classes, activation='softmax',
                            name='command_1')(cmd1)

    # ── Head 3: command 2 of sequence ─────────────────────────
    cmd2 = layers.Dense(256, activation='relu',
                        kernel_regularizer=keras.regularizers.l2(1e-4))(shared)
    cmd2 = layers.BatchNormalization()(cmd2)
    cmd2 = layers.Dropout(0.5)(cmd2)
    cmd2 = layers.Dense(128, activation='relu',
                        kernel_regularizer=keras.regularizers.l2(1e-4))(cmd2)
    cmd2 = layers.BatchNormalization()(cmd2)
    cmd2 = layers.Dropout(0.3)(cmd2)
    out_cmd2 = layers.Dense(num_classes, activation='softmax',
                            name='command_2')(cmd2)

    return models.Model(inputs, [out_single, out_cmd1, out_cmd2],
                        name='resnet_sequencing')

model = create_resnet_model(input_shape=(N_MELS, None, 1), num_classes=num_classes)
model.summary()
print(f"\nTotal parameters: {model.count_params():,}")
print(f"Model size: ~{model.count_params() * 4 / 1024 / 1024:.1f} MB")
# Out:
# Model: "resnet_sequencing"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, None, │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 64, None,  │      1,600 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64, None,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 64, None,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 32, None,  │          0 │ re_lu[0][0]       │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, None,  │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, None,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 32, None,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, None,  │     36,928 │ re_lu_1[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, None,  │      2,112 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, None,  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, None,  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, None,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 32, None,  │          0 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, None,  │     36,928 │ re_lu_2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, None,  │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 32, None,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, None,  │     36,928 │ re_lu_3[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, None,  │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 32, None,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ re_lu_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 32, None,  │          0 │ add_1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 32, None,  │          0 │ re_lu_4[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, None,  │     73,856 │ dropout[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, None,  │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 16, None,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, None,  │    147,584 │ re_lu_5[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, None,  │      8,320 │ dropout[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, None,  │        512 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, None,  │        512 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 16, None,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 16, None,  │          0 │ add_2[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, None,  │    147,584 │ re_lu_6[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, None,  │        512 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 16, None,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, None,  │    147,584 │ re_lu_7[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, None,  │        512 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, None,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ re_lu_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 16, None,  │          0 │ add_3[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 16, None,  │          0 │ re_lu_8[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 8, None,   │    295,168 │ dropout_1[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, None,   │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 8, None,   │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 8, None,   │    590,080 │ re_lu_9[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 8, None,   │     33,024 │ dropout_1[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, None,   │      1,024 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, None,   │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 8, None,   │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 8, None,   │          0 │ add_4[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 8, None,   │    590,080 │ re_lu_10[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, None,   │      1,024 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 8, None,   │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 8, None,   │    590,080 │ re_lu_11[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, None,   │      1,024 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 8, None,   │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ re_lu_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 8, None,   │          0 │ add_5[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ re_lu_12[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 16)        │      4,112 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │      4,352 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 256) │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 8, None,   │          0 │ re_lu_12[0][0],   │
# │                     │ 256)              │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 8, None,   │          0 │ multiply[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 4, None,   │  1,180,160 │ dropout_2[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, None,   │      2,048 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 4, None,   │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 4, None,   │  2,359,808 │ re_lu_13[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 4, None,   │    131,584 │ dropout_2[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, None,   │      2,048 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, None,   │      2,048 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 4, None,   │          0 │ batch_normalizat… │
# │                     │ 512)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 4, None,   │          0 │ add_6[0][0]       │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 4, None,   │  2,359,808 │ re_lu_14[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, None,   │      2,048 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 4, None,   │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 4, None,   │  2,359,808 │ re_lu_15[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, None,   │      2,048 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 4, None,   │          0 │ batch_normalizat… │
# │                     │ 512)              │            │ re_lu_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 4, None,   │          0 │ add_7[0][0]       │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ re_lu_16[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 32)        │     16,416 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 512)       │     16,896 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 512) │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 4, None,   │          0 │ re_lu_16[0][0],   │
# │ (Multiply)          │ 512)              │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 4, None,   │          0 │ multiply_1[0][0]  │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ dropout_3[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 256)       │    131,328 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │    131,328 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 256)       │    131,328 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_6[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_8[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │     32,896 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 128)       │     32,896 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 128)       │     32,896 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_5[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_7[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_9[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ single_command      │ (None, 11)        │      1,419 │ dropout_5[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ command_1 (Dense)   │ (None, 11)        │      1,419 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ command_2 (Dense)   │ (None, 11)        │      1,419 │ dropout_9[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,710,161 (44.67 MB)
#  Trainable params: 11,698,193 (44.63 MB)
#  Non-trainable params: 11,968 (46.75 KB)
# Total parameters: 11,710,161
# Model size: ~44.7 MB

# %%
def masked_sparse_crossentropy(y_true, y_pred):
    mask   = tf.cast(tf.not_equal(y_true, -1), tf.float32)
    y_true = tf.maximum(y_true, 0)
    loss   = keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
    return tf.reduce_sum(loss * mask) / (tf.reduce_sum(mask) + 1e-8)

EPOCHS        = 100
BATCH_SIZE    = 32
INITIAL_LR    = 1e-3
MIN_LR        = 1e-6
WARMUP_EPOCHS = 5

steps_per_epoch = len(train_generator)
total_steps     = steps_per_epoch * EPOCHS
warmup_steps    = steps_per_epoch * WARMUP_EPOCHS

print(f"  Epochs: {EPOCHS}")
print(f"  Steps per epoch: {steps_per_epoch}")
print(f"  Total steps: {total_steps:,}")
print(f"  Warmup steps: {warmup_steps} ({WARMUP_EPOCHS} epochs)")

lr_schedule = CosineDecayWithWarmup(
    initial_learning_rate=INITIAL_LR,
    decay_steps=total_steps,
    warmup_steps=warmup_steps,
    min_learning_rate=MIN_LR
)

# visualize LR schedule
steps_range = np.arange(0, total_steps, 100)
lrs = [float(lr_schedule(s)) for s in steps_range]
plt.figure(figsize=(10, 4))
plt.plot(steps_range / steps_per_epoch, lrs, 'b-', linewidth=2)
plt.axvline(x=WARMUP_EPOCHS, color='r', linestyle='--',
            label=f'Warmup ends (epoch {WARMUP_EPOCHS})')
plt.xlabel('Epoch')
plt.ylabel('Learning Rate')
plt.title('Cosine LR Schedule with Warmup')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
    loss={
        'single_command': masked_sparse_crossentropy,
        'command_1':      masked_sparse_crossentropy,
        'command_2':      masked_sparse_crossentropy
    },
    loss_weights={'single_command': 1.0, 'command_1': 1.0, 'command_2': 1.0},
    metrics={
        'single_command': 'accuracy',
        'command_1':      'accuracy',
        'command_2':      'accuracy'
    }
)
print("Model compiled with Adam optimizer and cosine LR schedule")
# Out:
#   Epochs: 100
#   Steps per epoch: 500
#   Total steps: 50,000
#   Warmup steps: 2500 (5 epochs)
# Model compiled with Adam optimizer and cosine LR schedule

# %%
from google.colab import drive
drive.mount('/content/drive')

DRIVE_DIR = f'/content/drive/MyDrive/{MODEL_NAME}'
os.makedirs(DRIVE_DIR, exist_ok=True)

callback_list = [
    callbacks.EarlyStopping(
        monitor='val_loss', patience=15,
        restore_best_weights=True, verbose=1
    ),
    callbacks.ModelCheckpoint(
        f'{DRIVE_DIR}/{MODEL_NAME}.keras',
        monitor='val_loss', save_best_only=True, verbose=1
    ),
    callbacks.CSVLogger('training_log.csv', append=False)
]

print("Callbacks configured — best model saves directly to Drive")
print(f"  Drive directory: {DRIVE_DIR}")
# Out:
# Mounted at /content/drive
# Callbacks configured — best model saves directly to Drive
#   Drive directory: /content/drive/MyDrive/resnet_sequencing

# %% [markdown]
# # Model Performace Analysis

# %%
print(f"Model: ResNet-18 with SE attention")
print(f"Augmentation: SpecAugment + noise mixing")
print(f"LR Schedule: Cosine decay with {WARMUP_EPOCHS}-epoch warmup")
print("=" * 60)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=callback_list,
    verbose=2
)

print("Finished training")
# Out:
# Model: ResNet-18 with SE attention
# Augmentation: SpecAugment + noise mixing
# LR Schedule: Cosine decay with 5-epoch warmup
# ============================================================
# Epoch 1/100
#
# Epoch 1: val_loss improved from None to 8.14783, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 157s - 315ms/step - command_1_accuracy: 0.0503 - command_1_loss: 3.0385 - command_2_accuracy: 0.0526 - command_2_loss: 3.0910 - loss: 10.0386 - single_command_accuracy: 0.0603 - single_command_loss: 2.7963 - val_command_1_accuracy: 0.0746 - val_command_1_loss: 2.3588 - val_command_2_accuracy: 0.0706 - val_command_2_loss: 2.4636 - val_loss: 8.1478 - val_single_command_accuracy: 0.0935 - val_single_command_loss: 2.2175
# Epoch 2/100
#
# Epoch 2: val_loss did not improve from 8.14783
# 500/500 - 83s - 167ms/step - command_1_accuracy: 0.0653 - command_1_loss: 2.5195 - command_2_accuracy: 0.0717 - command_2_loss: 2.5132 - loss: 8.4353 - single_command_accuracy: 0.0926 - single_command_loss: 2.2962 - val_command_1_accuracy: 0.0669 - val_command_1_loss: 2.4088 - val_command_2_accuracy: 0.0623 - val_command_2_loss: 2.6339 - val_loss: 8.5056 - val_single_command_accuracy: 0.0799 - val_single_command_loss: 2.3570
# Epoch 3/100
#
# Epoch 3: val_loss improved from 8.14783 to 5.44075, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 81s - 162ms/step - command_1_accuracy: 0.1322 - command_1_loss: 2.0245 - command_2_accuracy: 0.1461 - command_2_loss: 1.9815 - loss: 6.8302 - single_command_accuracy: 0.1840 - single_command_loss: 1.7185 - val_command_1_accuracy: 0.1804 - val_command_1_loss: 1.8885 - val_command_2_accuracy: 0.2503 - val_command_2_loss: 1.3657 - val_loss: 5.4408 - val_single_command_accuracy: 0.3006 - val_single_command_loss: 1.0787
# Epoch 4/100
#
# Epoch 4: val_loss improved from 5.44075 to 3.87420, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 88s - 175ms/step - command_1_accuracy: 0.3128 - command_1_loss: 1.0422 - command_2_accuracy: 0.3128 - command_2_loss: 1.0341 - loss: 4.0588 - single_command_accuracy: 0.3411 - single_command_loss: 0.8712 - val_command_1_accuracy: 0.3762 - val_command_1_loss: 0.7211 - val_command_2_accuracy: 0.3392 - val_command_2_loss: 1.1210 - val_loss: 3.8742 - val_single_command_accuracy: 0.3642 - val_single_command_loss: 0.9187
# Epoch 5/100
#
# Epoch 5: val_loss improved from 3.87420 to 2.80940, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 88s - 175ms/step - command_1_accuracy: 0.3856 - command_1_loss: 0.6803 - command_2_accuracy: 0.3869 - command_2_loss: 0.6709 - loss: 3.0642 - single_command_accuracy: 0.3986 - single_command_loss: 0.5966 - val_command_1_accuracy: 0.4061 - val_command_1_loss: 0.6207 - val_command_2_accuracy: 0.4035 - val_command_2_loss: 0.6946 - val_loss: 2.8094 - val_single_command_accuracy: 0.4447 - val_single_command_loss: 0.3781
# Epoch 6/100
#
# Epoch 6: val_loss improved from 2.80940 to 2.15198, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 87s - 174ms/step - command_1_accuracy: 0.4226 - command_1_loss: 0.4970 - command_2_accuracy: 0.4210 - command_2_loss: 0.5013 - loss: 2.5660 - single_command_accuracy: 0.4297 - single_command_loss: 0.4520 - val_command_1_accuracy: 0.4304 - val_command_1_loss: 0.4135 - val_command_2_accuracy: 0.4404 - val_command_2_loss: 0.3415 - val_loss: 2.1520 - val_single_command_accuracy: 0.4507 - val_single_command_loss: 0.2857
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 2.15198
# 500/500 - 88s - 177ms/step - command_1_accuracy: 0.4371 - command_1_loss: 0.4098 - command_2_accuracy: 0.4387 - command_2_loss: 0.3971 - loss: 2.3064 - single_command_accuracy: 0.4380 - single_command_loss: 0.3932 - val_command_1_accuracy: 0.4234 - val_command_1_loss: 0.5342 - val_command_2_accuracy: 0.4471 - val_command_2_loss: 0.3785 - val_loss: 2.3644 - val_single_command_accuracy: 0.4524 - val_single_command_loss: 0.3521
# Epoch 8/100
#
# Epoch 8: val_loss improved from 2.15198 to 2.04511, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 82s - 165ms/step - command_1_accuracy: 0.4446 - command_1_loss: 0.3634 - command_2_accuracy: 0.4446 - command_2_loss: 0.3668 - loss: 2.1880 - single_command_accuracy: 0.4427 - single_command_loss: 0.3660 - val_command_1_accuracy: 0.4571 - val_command_1_loss: 0.2882 - val_command_2_accuracy: 0.4547 - val_command_2_loss: 0.3439 - val_loss: 2.0451 - val_single_command_accuracy: 0.4461 - val_single_command_loss: 0.3304
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 2.04511
# 500/500 - 84s - 169ms/step - command_1_accuracy: 0.4490 - command_1_loss: 0.3378 - command_2_accuracy: 0.4519 - command_2_loss: 0.3217 - loss: 2.0623 - single_command_accuracy: 0.4504 - single_command_loss: 0.3318 - val_command_1_accuracy: 0.4501 - val_command_1_loss: 0.3489 - val_command_2_accuracy: 0.4461 - val_command_2_loss: 0.3932 - val_loss: 2.0996 - val_single_command_accuracy: 0.4491 - val_single_command_loss: 0.3003
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 2.04511
# 500/500 - 85s - 169ms/step - command_1_accuracy: 0.4493 - command_1_loss: 0.3205 - command_2_accuracy: 0.4523 - command_2_loss: 0.3215 - loss: 2.0120 - single_command_accuracy: 0.4496 - single_command_loss: 0.3250 - val_command_1_accuracy: 0.4494 - val_command_1_loss: 0.3361 - val_command_2_accuracy: 0.4204 - val_command_2_loss: 0.6121 - val_loss: 2.2931 - val_single_command_accuracy: 0.4507 - val_single_command_loss: 0.3141
# Epoch 11/100
#
# Epoch 11: val_loss improved from 2.04511 to 1.82417, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 82s - 165ms/step - command_1_accuracy: 0.4548 - command_1_loss: 0.3021 - command_2_accuracy: 0.4546 - command_2_loss: 0.2891 - loss: 1.8986 - single_command_accuracy: 0.4580 - single_command_loss: 0.2886 - val_command_1_accuracy: 0.4551 - val_command_1_loss: 0.3159 - val_command_2_accuracy: 0.4601 - val_command_2_loss: 0.2801 - val_loss: 1.8242 - val_single_command_accuracy: 0.4654 - val_single_command_loss: 0.2256
# Epoch 12/100
#
# Epoch 12: val_loss improved from 1.82417 to 1.79014, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 86s - 172ms/step - command_1_accuracy: 0.4573 - command_1_loss: 0.2795 - command_2_accuracy: 0.4579 - command_2_loss: 0.2776 - loss: 1.8478 - single_command_accuracy: 0.4564 - single_command_loss: 0.3001 - val_command_1_accuracy: 0.4594 - val_command_1_loss: 0.2825 - val_command_2_accuracy: 0.4544 - val_command_2_loss: 0.3147 - val_loss: 1.7901 - val_single_command_accuracy: 0.4667 - val_single_command_loss: 0.2157
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 1.79014
# 500/500 - 87s - 173ms/step - command_1_accuracy: 0.4586 - command_1_loss: 0.2734 - command_2_accuracy: 0.4604 - command_2_loss: 0.2556 - loss: 1.7775 - single_command_accuracy: 0.4570 - single_command_loss: 0.2843 - val_command_1_accuracy: 0.4184 - val_command_1_loss: 0.5344 - val_command_2_accuracy: 0.3688 - val_command_2_loss: 1.0647 - val_loss: 3.0518 - val_single_command_accuracy: 0.4158 - val_single_command_loss: 0.5010
# Epoch 14/100
#
# Epoch 14: val_loss improved from 1.79014 to 1.57246, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 82s - 165ms/step - command_1_accuracy: 0.4601 - command_1_loss: 0.2590 - command_2_accuracy: 0.4638 - command_2_loss: 0.2437 - loss: 1.7080 - single_command_accuracy: 0.4616 - single_command_loss: 0.2634 - val_command_1_accuracy: 0.4627 - val_command_1_loss: 0.2471 - val_command_2_accuracy: 0.4680 - val_command_2_loss: 0.2332 - val_loss: 1.5725 - val_single_command_accuracy: 0.4780 - val_single_command_loss: 0.1611
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 1.57246
# 500/500 - 84s - 169ms/step - command_1_accuracy: 0.4618 - command_1_loss: 0.2625 - command_2_accuracy: 0.4616 - command_2_loss: 0.2644 - loss: 1.7265 - single_command_accuracy: 0.4586 - single_command_loss: 0.2786 - val_command_1_accuracy: 0.4611 - val_command_1_loss: 0.2800 - val_command_2_accuracy: 0.4561 - val_command_2_loss: 0.3468 - val_loss: 1.7253 - val_single_command_accuracy: 0.4740 - val_single_command_loss: 0.1827
# Epoch 16/100
#
# Epoch 16: val_loss improved from 1.57246 to 1.52033, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 16: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 86s - 172ms/step - command_1_accuracy: 0.4622 - command_1_loss: 0.2536 - command_2_accuracy: 0.4639 - command_2_loss: 0.2400 - loss: 1.6728 - single_command_accuracy: 0.4600 - single_command_loss: 0.2763 - val_command_1_accuracy: 0.4684 - val_command_1_loss: 0.1946 - val_command_2_accuracy: 0.4630 - val_command_2_loss: 0.2682 - val_loss: 1.5203 - val_single_command_accuracy: 0.4797 - val_single_command_loss: 0.1599
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 1.52033
# 500/500 - 86s - 171ms/step - command_1_accuracy: 0.4612 - command_1_loss: 0.2602 - command_2_accuracy: 0.4629 - command_2_loss: 0.2514 - loss: 1.6614 - single_command_accuracy: 0.4640 - single_command_loss: 0.2523 - val_command_1_accuracy: 0.4364 - val_command_1_loss: 0.5107 - val_command_2_accuracy: 0.4411 - val_command_2_loss: 0.4478 - val_loss: 2.1468 - val_single_command_accuracy: 0.4564 - val_single_command_loss: 0.2904
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 1.52033
# 500/500 - 82s - 163ms/step - command_1_accuracy: 0.4659 - command_1_loss: 0.2369 - command_2_accuracy: 0.4672 - command_2_loss: 0.2183 - loss: 1.5800 - single_command_accuracy: 0.4644 - single_command_loss: 0.2387 - val_command_1_accuracy: 0.4601 - val_command_1_loss: 0.2504 - val_command_2_accuracy: 0.4497 - val_command_2_loss: 0.3881 - val_loss: 1.7447 - val_single_command_accuracy: 0.4634 - val_single_command_loss: 0.2210
# Epoch 19/100
#
# Epoch 19: val_loss improved from 1.52033 to 1.49159, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 19: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 85s - 170ms/step - command_1_accuracy: 0.4660 - command_1_loss: 0.2339 - command_2_accuracy: 0.4676 - command_2_loss: 0.2177 - loss: 1.6023 - single_command_accuracy: 0.4608 - single_command_loss: 0.2680 - val_command_1_accuracy: 0.4581 - val_command_1_loss: 0.2682 - val_command_2_accuracy: 0.4747 - val_command_2_loss: 0.1924 - val_loss: 1.4916 - val_single_command_accuracy: 0.4760 - val_single_command_loss: 0.1527
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 1.49159
# 500/500 - 86s - 172ms/step - command_1_accuracy: 0.4676 - command_1_loss: 0.2182 - command_2_accuracy: 0.4675 - command_2_loss: 0.2263 - loss: 1.5558 - single_command_accuracy: 0.4645 - single_command_loss: 0.2412 - val_command_1_accuracy: 0.4617 - val_command_1_loss: 0.2609 - val_command_2_accuracy: 0.4554 - val_command_2_loss: 0.3213 - val_loss: 1.7098 - val_single_command_accuracy: 0.4634 - val_single_command_loss: 0.2630
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 1.49159
# 500/500 - 81s - 162ms/step - command_1_accuracy: 0.4671 - command_1_loss: 0.2182 - command_2_accuracy: 0.4709 - command_2_loss: 0.2012 - loss: 1.5222 - single_command_accuracy: 0.4642 - single_command_loss: 0.2462 - val_command_1_accuracy: 0.4617 - val_command_1_loss: 0.2674 - val_command_2_accuracy: 0.4634 - val_command_2_loss: 0.3051 - val_loss: 1.6745 - val_single_command_accuracy: 0.4647 - val_single_command_loss: 0.2529
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 1.49159
# 500/500 - 83s - 165ms/step - command_1_accuracy: 0.4710 - command_1_loss: 0.2034 - command_2_accuracy: 0.4703 - command_2_loss: 0.2141 - loss: 1.5047 - single_command_accuracy: 0.4663 - single_command_loss: 0.2386 - val_command_1_accuracy: 0.4647 - val_command_1_loss: 0.2795 - val_command_2_accuracy: 0.4484 - val_command_2_loss: 0.4024 - val_loss: 1.6983 - val_single_command_accuracy: 0.4744 - val_single_command_loss: 0.1783
# Epoch 23/100
#
# Epoch 23: val_loss improved from 1.49159 to 1.37042, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 23: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 82s - 165ms/step - command_1_accuracy: 0.4702 - command_1_loss: 0.2098 - command_2_accuracy: 0.4704 - command_2_loss: 0.1973 - loss: 1.4883 - single_command_accuracy: 0.4652 - single_command_loss: 0.2365 - val_command_1_accuracy: 0.4674 - val_command_1_loss: 0.1983 - val_command_2_accuracy: 0.4750 - val_command_2_loss: 0.1779 - val_loss: 1.3704 - val_single_command_accuracy: 0.4777 - val_single_command_loss: 0.1551
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 1.37042
# 500/500 - 84s - 168ms/step - command_1_accuracy: 0.4691 - command_1_loss: 0.2141 - command_2_accuracy: 0.4723 - command_2_loss: 0.1908 - loss: 1.4652 - single_command_accuracy: 0.4681 - single_command_loss: 0.2307 - val_command_1_accuracy: 0.4740 - val_command_1_loss: 0.1834 - val_command_2_accuracy: 0.4647 - val_command_2_loss: 0.2578 - val_loss: 1.4384 - val_single_command_accuracy: 0.4777 - val_single_command_loss: 0.1648
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 1.37042
# 500/500 - 80s - 159ms/step - command_1_accuracy: 0.4761 - command_1_loss: 0.1754 - command_2_accuracy: 0.4732 - command_2_loss: 0.1768 - loss: 1.3796 - single_command_accuracy: 0.4698 - single_command_loss: 0.2151 - val_command_1_accuracy: 0.4531 - val_command_1_loss: 0.3695 - val_command_2_accuracy: 0.4664 - val_command_2_loss: 0.2438 - val_loss: 1.6407 - val_single_command_accuracy: 0.4684 - val_single_command_loss: 0.2171
# Epoch 26/100
#
# Epoch 26: val_loss improved from 1.37042 to 1.31308, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 26: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 80s - 159ms/step - command_1_accuracy: 0.4728 - command_1_loss: 0.1890 - command_2_accuracy: 0.4725 - command_2_loss: 0.1869 - loss: 1.4089 - single_command_accuracy: 0.4673 - single_command_loss: 0.2266 - val_command_1_accuracy: 0.4724 - val_command_1_loss: 0.1828 - val_command_2_accuracy: 0.4677 - val_command_2_loss: 0.1982 - val_loss: 1.3131 - val_single_command_accuracy: 0.4807 - val_single_command_loss: 0.1366
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 1.31308
# 500/500 - 83s - 165ms/step - command_1_accuracy: 0.4742 - command_1_loss: 0.1780 - command_2_accuracy: 0.4708 - command_2_loss: 0.1959 - loss: 1.3734 - single_command_accuracy: 0.4701 - single_command_loss: 0.2073 - val_command_1_accuracy: 0.4611 - val_command_1_loss: 0.2952 - val_command_2_accuracy: 0.4740 - val_command_2_loss: 0.2285 - val_loss: 1.4900 - val_single_command_accuracy: 0.4780 - val_single_command_loss: 0.1699
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 1.31308
# 500/500 - 79s - 158ms/step - command_1_accuracy: 0.4749 - command_1_loss: 0.1801 - command_2_accuracy: 0.4777 - command_2_loss: 0.1606 - loss: 1.3282 - single_command_accuracy: 0.4703 - single_command_loss: 0.2051 - val_command_1_accuracy: 0.4427 - val_command_1_loss: 0.4097 - val_command_2_accuracy: 0.4507 - val_command_2_loss: 0.3717 - val_loss: 1.7760 - val_single_command_accuracy: 0.4687 - val_single_command_loss: 0.2250
# Epoch 29/100
#
# Epoch 29: val_loss improved from 1.31308 to 1.19479, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 29: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 80s - 160ms/step - command_1_accuracy: 0.4776 - command_1_loss: 0.1664 - command_2_accuracy: 0.4741 - command_2_loss: 0.1743 - loss: 1.3024 - single_command_accuracy: 0.4706 - single_command_loss: 0.1970 - val_command_1_accuracy: 0.4794 - val_command_1_loss: 0.1399 - val_command_2_accuracy: 0.4757 - val_command_2_loss: 0.1579 - val_loss: 1.1948 - val_single_command_accuracy: 0.4790 - val_single_command_loss: 0.1401
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 1.19479
# 500/500 - 85s - 170ms/step - command_1_accuracy: 0.4762 - command_1_loss: 0.1669 - command_2_accuracy: 0.4773 - command_2_loss: 0.1694 - loss: 1.2704 - single_command_accuracy: 0.4729 - single_command_loss: 0.1852 - val_command_1_accuracy: 0.4660 - val_command_1_loss: 0.2421 - val_command_2_accuracy: 0.4660 - val_command_2_loss: 0.2349 - val_loss: 1.4019 - val_single_command_accuracy: 0.4717 - val_single_command_loss: 0.1781
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 1.19479
# 500/500 - 77s - 155ms/step - command_1_accuracy: 0.4793 - command_1_loss: 0.1499 - command_2_accuracy: 0.4792 - command_2_loss: 0.1438 - loss: 1.2088 - single_command_accuracy: 0.4746 - single_command_loss: 0.1810 - val_command_1_accuracy: 0.4694 - val_command_1_loss: 0.2158 - val_command_2_accuracy: 0.4764 - val_command_2_loss: 0.1775 - val_loss: 1.2947 - val_single_command_accuracy: 0.4790 - val_single_command_loss: 0.1783
# Epoch 32/100
#
# Epoch 32: val_loss improved from 1.19479 to 1.18721, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 32: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 78s - 156ms/step - command_1_accuracy: 0.4789 - command_1_loss: 0.1443 - command_2_accuracy: 0.4789 - command_2_loss: 0.1503 - loss: 1.1915 - single_command_accuracy: 0.4737 - single_command_loss: 0.1827 - val_command_1_accuracy: 0.4757 - val_command_1_loss: 0.1570 - val_command_2_accuracy: 0.4737 - val_command_2_loss: 0.1874 - val_loss: 1.1872 - val_single_command_accuracy: 0.4787 - val_single_command_loss: 0.1376
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 1.18721
# 500/500 - 81s - 162ms/step - command_1_accuracy: 0.4773 - command_1_loss: 0.1588 - command_2_accuracy: 0.4789 - command_2_loss: 0.1498 - loss: 1.2080 - single_command_accuracy: 0.4723 - single_command_loss: 0.1934 - val_command_1_accuracy: 0.4707 - val_command_1_loss: 0.2321 - val_command_2_accuracy: 0.4677 - val_command_2_loss: 0.2826 - val_loss: 1.3682 - val_single_command_accuracy: 0.4797 - val_single_command_loss: 0.1501
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 1.18721
# 500/500 - 78s - 156ms/step - command_1_accuracy: 0.4800 - command_1_loss: 0.1460 - command_2_accuracy: 0.4805 - command_2_loss: 0.1348 - loss: 1.1636 - single_command_accuracy: 0.4723 - single_command_loss: 0.1864 - val_command_1_accuracy: 0.4804 - val_command_1_loss: 0.1295 - val_command_2_accuracy: 0.4697 - val_command_2_loss: 0.2696 - val_loss: 1.2335 - val_single_command_accuracy: 0.4787 - val_single_command_loss: 0.1416
# Epoch 35/100
#
# Epoch 35: val_loss improved from 1.18721 to 1.13129, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 35: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 80s - 161ms/step - command_1_accuracy: 0.4803 - command_1_loss: 0.1269 - command_2_accuracy: 0.4819 - command_2_loss: 0.1256 - loss: 1.1084 - single_command_accuracy: 0.4749 - single_command_loss: 0.1731 - val_command_1_accuracy: 0.4764 - val_command_1_loss: 0.1741 - val_command_2_accuracy: 0.4777 - val_command_2_loss: 0.1599 - val_loss: 1.1313 - val_single_command_accuracy: 0.4797 - val_single_command_loss: 0.1190
# Epoch 36/100
#
# Epoch 36: val_loss improved from 1.13129 to 1.08592, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 36: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 82s - 164ms/step - command_1_accuracy: 0.4818 - command_1_loss: 0.1319 - command_2_accuracy: 0.4796 - command_2_loss: 0.1423 - loss: 1.1152 - single_command_accuracy: 0.4768 - single_command_loss: 0.1693 - val_command_1_accuracy: 0.4767 - val_command_1_loss: 0.1401 - val_command_2_accuracy: 0.4794 - val_command_2_loss: 0.1829 - val_loss: 1.0859 - val_single_command_accuracy: 0.4834 - val_single_command_loss: 0.0993
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 1.08592
# 500/500 - 84s - 168ms/step - command_1_accuracy: 0.4818 - command_1_loss: 0.1283 - command_2_accuracy: 0.4814 - command_2_loss: 0.1365 - loss: 1.0801 - single_command_accuracy: 0.4776 - single_command_loss: 0.1587 - val_command_1_accuracy: 0.4677 - val_command_1_loss: 0.2601 - val_command_2_accuracy: 0.4760 - val_command_2_loss: 0.2050 - val_loss: 1.2660 - val_single_command_accuracy: 0.4784 - val_single_command_loss: 0.1529
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 1.08592
# 500/500 - 79s - 157ms/step - command_1_accuracy: 0.4823 - command_1_loss: 0.1269 - command_2_accuracy: 0.4830 - command_2_loss: 0.1194 - loss: 1.0572 - single_command_accuracy: 0.4761 - single_command_loss: 0.1691 - val_command_1_accuracy: 0.4720 - val_command_1_loss: 0.1704 - val_command_2_accuracy: 0.4710 - val_command_2_loss: 0.2227 - val_loss: 1.1818 - val_single_command_accuracy: 0.4784 - val_single_command_loss: 0.1504
# Epoch 39/100
#
# Epoch 39: val_loss improved from 1.08592 to 1.01801, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 39: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 83s - 166ms/step - command_1_accuracy: 0.4816 - command_1_loss: 0.1220 - command_2_accuracy: 0.4825 - command_2_loss: 0.1332 - loss: 1.0661 - single_command_accuracy: 0.4746 - single_command_loss: 0.1740 - val_command_1_accuracy: 0.4787 - val_command_1_loss: 0.1291 - val_command_2_accuracy: 0.4800 - val_command_2_loss: 0.1468 - val_loss: 1.0180 - val_single_command_accuracy: 0.4834 - val_single_command_loss: 0.1099
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 1.01801
# 500/500 - 81s - 163ms/step - command_1_accuracy: 0.4823 - command_1_loss: 0.1212 - command_2_accuracy: 0.4846 - command_2_loss: 0.1051 - loss: 1.0055 - single_command_accuracy: 0.4776 - single_command_loss: 0.1550 - val_command_1_accuracy: 0.4680 - val_command_1_loss: 0.2251 - val_command_2_accuracy: 0.4650 - val_command_2_loss: 0.3055 - val_loss: 1.3483 - val_single_command_accuracy: 0.4710 - val_single_command_loss: 0.2034
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 1.01801
# 500/500 - 81s - 162ms/step - command_1_accuracy: 0.4844 - command_1_loss: 0.1185 - command_2_accuracy: 0.4838 - command_2_loss: 0.1165 - loss: 1.0024 - single_command_accuracy: 0.4768 - single_command_loss: 0.1556 - val_command_1_accuracy: 0.4790 - val_command_1_loss: 0.1342 - val_command_2_accuracy: 0.4774 - val_command_2_loss: 0.1636 - val_loss: 1.0603 - val_single_command_accuracy: 0.4777 - val_single_command_loss: 0.1552
# Epoch 42/100
#
# Epoch 42: val_loss improved from 1.01801 to 1.01703, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 42: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 80s - 160ms/step - command_1_accuracy: 0.4852 - command_1_loss: 0.0986 - command_2_accuracy: 0.4847 - command_2_loss: 0.1058 - loss: 0.9748 - single_command_accuracy: 0.4759 - single_command_loss: 0.1654 - val_command_1_accuracy: 0.4797 - val_command_1_loss: 0.1405 - val_command_2_accuracy: 0.4794 - val_command_2_loss: 0.1571 - val_loss: 1.0170 - val_single_command_accuracy: 0.4830 - val_single_command_loss: 0.1224
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 1.01703
# 500/500 - 83s - 166ms/step - command_1_accuracy: 0.4843 - command_1_loss: 0.1066 - command_2_accuracy: 0.4853 - command_2_loss: 0.1034 - loss: 0.9471 - single_command_accuracy: 0.4796 - single_command_loss: 0.1434 - val_command_1_accuracy: 0.4770 - val_command_1_loss: 0.1729 - val_command_2_accuracy: 0.4714 - val_command_2_loss: 0.1851 - val_loss: 1.0969 - val_single_command_accuracy: 0.4800 - val_single_command_loss: 0.1493
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 1.01703
# 500/500 - 79s - 157ms/step - command_1_accuracy: 0.4856 - command_1_loss: 0.1036 - command_2_accuracy: 0.4871 - command_2_loss: 0.0977 - loss: 0.9373 - single_command_accuracy: 0.4792 - single_command_loss: 0.1515 - val_command_1_accuracy: 0.4757 - val_command_1_loss: 0.1816 - val_command_2_accuracy: 0.4787 - val_command_2_loss: 0.1928 - val_loss: 1.0937 - val_single_command_accuracy: 0.4814 - val_single_command_loss: 0.1349
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 1.01703
# 500/500 - 78s - 157ms/step - command_1_accuracy: 0.4854 - command_1_loss: 0.1021 - command_2_accuracy: 0.4865 - command_2_loss: 0.0954 - loss: 0.9142 - single_command_accuracy: 0.4806 - single_command_loss: 0.1387 - val_command_1_accuracy: 0.4720 - val_command_1_loss: 0.1913 - val_command_2_accuracy: 0.4767 - val_command_2_loss: 0.1986 - val_loss: 1.1068 - val_single_command_accuracy: 0.4787 - val_single_command_loss: 0.1449
# Epoch 46/100
#
# Epoch 46: val_loss improved from 1.01703 to 0.98856, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 46: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 83s - 166ms/step - command_1_accuracy: 0.4876 - command_1_loss: 0.0837 - command_2_accuracy: 0.4868 - command_2_loss: 0.0982 - loss: 0.8869 - single_command_accuracy: 0.4801 - single_command_loss: 0.1371 - val_command_1_accuracy: 0.4794 - val_command_1_loss: 0.1391 - val_command_2_accuracy: 0.4764 - val_command_2_loss: 0.1733 - val_loss: 0.9886 - val_single_command_accuracy: 0.4830 - val_single_command_loss: 0.1122
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.98856
# 500/500 - 82s - 163ms/step - command_1_accuracy: 0.4874 - command_1_loss: 0.0920 - command_2_accuracy: 0.4872 - command_2_loss: 0.0865 - loss: 0.8784 - single_command_accuracy: 0.4805 - single_command_loss: 0.1399 - val_command_1_accuracy: 0.4727 - val_command_1_loss: 0.2325 - val_command_2_accuracy: 0.4710 - val_command_2_loss: 0.2337 - val_loss: 1.1642 - val_single_command_accuracy: 0.4787 - val_single_command_loss: 0.1407
# Epoch 48/100
#
# Epoch 48: val_loss improved from 0.98856 to 0.92968, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 48: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 82s - 164ms/step - command_1_accuracy: 0.4873 - command_1_loss: 0.0946 - command_2_accuracy: 0.4892 - command_2_loss: 0.0795 - loss: 0.8689 - single_command_accuracy: 0.4787 - single_command_loss: 0.1442 - val_command_1_accuracy: 0.4797 - val_command_1_loss: 0.1205 - val_command_2_accuracy: 0.4787 - val_command_2_loss: 0.1414 - val_loss: 0.9297 - val_single_command_accuracy: 0.4850 - val_single_command_loss: 0.1197
# Epoch 49/100
#
# Epoch 49: val_loss improved from 0.92968 to 0.91788, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 49: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 83s - 166ms/step - command_1_accuracy: 0.4893 - command_1_loss: 0.0747 - command_2_accuracy: 0.4877 - command_2_loss: 0.0890 - loss: 0.8402 - single_command_accuracy: 0.4811 - single_command_loss: 0.1339 - val_command_1_accuracy: 0.4820 - val_command_1_loss: 0.1267 - val_command_2_accuracy: 0.4834 - val_command_2_loss: 0.1562 - val_loss: 0.9179 - val_single_command_accuracy: 0.4864 - val_single_command_loss: 0.0960
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.91788
# 500/500 - 80s - 160ms/step - command_1_accuracy: 0.4891 - command_1_loss: 0.0766 - command_2_accuracy: 0.4889 - command_2_loss: 0.0805 - loss: 0.8230 - single_command_accuracy: 0.4815 - single_command_loss: 0.1318 - val_command_1_accuracy: 0.4754 - val_command_1_loss: 0.1909 - val_command_2_accuracy: 0.4777 - val_command_2_loss: 0.1913 - val_loss: 1.0203 - val_single_command_accuracy: 0.4867 - val_single_command_loss: 0.1092
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.91788
# 500/500 - 78s - 157ms/step - command_1_accuracy: 0.4897 - command_1_loss: 0.0761 - command_2_accuracy: 0.4888 - command_2_loss: 0.0740 - loss: 0.7989 - single_command_accuracy: 0.4829 - single_command_loss: 0.1245 - val_command_1_accuracy: 0.4830 - val_command_1_loss: 0.1274 - val_command_2_accuracy: 0.4784 - val_command_2_loss: 0.1832 - val_loss: 0.9378 - val_single_command_accuracy: 0.4850 - val_single_command_loss: 0.1082
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.91788
# 500/500 - 81s - 163ms/step - command_1_accuracy: 0.4868 - command_1_loss: 0.0921 - command_2_accuracy: 0.4906 - command_2_loss: 0.0652 - loss: 0.8208 - single_command_accuracy: 0.4801 - single_command_loss: 0.1463 - val_command_1_accuracy: 0.4777 - val_command_1_loss: 0.1551 - val_command_2_accuracy: 0.4820 - val_command_2_loss: 0.1731 - val_loss: 0.9752 - val_single_command_accuracy: 0.4837 - val_single_command_loss: 0.1339
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.91788
# 500/500 - 79s - 158ms/step - command_1_accuracy: 0.4905 - command_1_loss: 0.0665 - command_2_accuracy: 0.4908 - command_2_loss: 0.0674 - loss: 0.7649 - single_command_accuracy: 0.4820 - single_command_loss: 0.1214 - val_command_1_accuracy: 0.4830 - val_command_1_loss: 0.1420 - val_command_2_accuracy: 0.4814 - val_command_2_loss: 0.1645 - val_loss: 0.9406 - val_single_command_accuracy: 0.4804 - val_single_command_loss: 0.1309
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.91788
# 500/500 - 77s - 154ms/step - command_1_accuracy: 0.4914 - command_1_loss: 0.0608 - command_2_accuracy: 0.4883 - command_2_loss: 0.0847 - loss: 0.7710 - single_command_accuracy: 0.4831 - single_command_loss: 0.1253 - val_command_1_accuracy: 0.4810 - val_command_1_loss: 0.1491 - val_command_2_accuracy: 0.4784 - val_command_2_loss: 0.1617 - val_loss: 0.9508 - val_single_command_accuracy: 0.4807 - val_single_command_loss: 0.1423
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.91788
# 500/500 - 78s - 157ms/step - command_1_accuracy: 0.4889 - command_1_loss: 0.0777 - command_2_accuracy: 0.4907 - command_2_loss: 0.0684 - loss: 0.7565 - single_command_accuracy: 0.4838 - single_command_loss: 0.1164 - val_command_1_accuracy: 0.4800 - val_command_1_loss: 0.1508 - val_command_2_accuracy: 0.4794 - val_command_2_loss: 0.1901 - val_loss: 0.9433 - val_single_command_accuracy: 0.4824 - val_single_command_loss: 0.1144
# Epoch 56/100
#
# Epoch 56: val_loss improved from 0.91788 to 0.88551, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 56: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 78s - 156ms/step - command_1_accuracy: 0.4920 - command_1_loss: 0.0594 - command_2_accuracy: 0.4915 - command_2_loss: 0.0683 - loss: 0.7254 - single_command_accuracy: 0.4847 - single_command_loss: 0.1142 - val_command_1_accuracy: 0.4810 - val_command_1_loss: 0.1445 - val_command_2_accuracy: 0.4817 - val_command_2_loss: 0.1462 - val_loss: 0.8855 - val_single_command_accuracy: 0.4814 - val_single_command_loss: 0.1161
# Epoch 57/100
#
# Epoch 57: val_loss improved from 0.88551 to 0.80056, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 57: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 87s - 174ms/step - command_1_accuracy: 0.4899 - command_1_loss: 0.0694 - command_2_accuracy: 0.4909 - command_2_loss: 0.0642 - loss: 0.7227 - single_command_accuracy: 0.4841 - single_command_loss: 0.1139 - val_command_1_accuracy: 0.4820 - val_command_1_loss: 0.1232 - val_command_2_accuracy: 0.4840 - val_command_2_loss: 0.1317 - val_loss: 0.8006 - val_single_command_accuracy: 0.4913 - val_single_command_loss: 0.0733
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.80056
# 500/500 - 82s - 163ms/step - command_1_accuracy: 0.4915 - command_1_loss: 0.0616 - command_2_accuracy: 0.4916 - command_2_loss: 0.0559 - loss: 0.7062 - single_command_accuracy: 0.4830 - single_command_loss: 0.1194 - val_command_1_accuracy: 0.4804 - val_command_1_loss: 0.1616 - val_command_2_accuracy: 0.4807 - val_command_2_loss: 0.1709 - val_loss: 0.9032 - val_single_command_accuracy: 0.4830 - val_single_command_loss: 0.1057
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.80056
# 500/500 - 79s - 157ms/step - command_1_accuracy: 0.4920 - command_1_loss: 0.0572 - command_2_accuracy: 0.4924 - command_2_loss: 0.0581 - loss: 0.6867 - single_command_accuracy: 0.4856 - single_command_loss: 0.1090 - val_command_1_accuracy: 0.4797 - val_command_1_loss: 0.1501 - val_command_2_accuracy: 0.4807 - val_command_2_loss: 0.1589 - val_loss: 0.8632 - val_single_command_accuracy: 0.4874 - val_single_command_loss: 0.0957
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.80056
# 500/500 - 78s - 156ms/step - command_1_accuracy: 0.4921 - command_1_loss: 0.0550 - command_2_accuracy: 0.4926 - command_2_loss: 0.0517 - loss: 0.6728 - single_command_accuracy: 0.4844 - single_command_loss: 0.1103 - val_command_1_accuracy: 0.4847 - val_command_1_loss: 0.1163 - val_command_2_accuracy: 0.4827 - val_command_2_loss: 0.1744 - val_loss: 0.8295 - val_single_command_accuracy: 0.4903 - val_single_command_loss: 0.0859
# Epoch 61/100
#
# Epoch 61: val_loss improved from 0.80056 to 0.77243, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 61: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 78s - 156ms/step - command_1_accuracy: 0.4924 - command_1_loss: 0.0550 - command_2_accuracy: 0.4925 - command_2_loss: 0.0508 - loss: 0.6511 - single_command_accuracy: 0.4859 - single_command_loss: 0.0964 - val_command_1_accuracy: 0.4850 - val_command_1_loss: 0.1046 - val_command_2_accuracy: 0.4850 - val_command_2_loss: 0.1358 - val_loss: 0.7724 - val_single_command_accuracy: 0.4880 - val_single_command_loss: 0.0873
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.77243
# 500/500 - 82s - 163ms/step - command_1_accuracy: 0.4918 - command_1_loss: 0.0609 - command_2_accuracy: 0.4931 - command_2_loss: 0.0508 - loss: 0.6569 - single_command_accuracy: 0.4849 - single_command_loss: 0.1024 - val_command_1_accuracy: 0.4820 - val_command_1_loss: 0.1214 - val_command_2_accuracy: 0.4807 - val_command_2_loss: 0.1771 - val_loss: 0.8292 - val_single_command_accuracy: 0.4893 - val_single_command_loss: 0.0904
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.77243
# 500/500 - 79s - 158ms/step - command_1_accuracy: 0.4939 - command_1_loss: 0.0439 - command_2_accuracy: 0.4932 - command_2_loss: 0.0495 - loss: 0.6144 - single_command_accuracy: 0.4878 - single_command_loss: 0.0849 - val_command_1_accuracy: 0.4817 - val_command_1_loss: 0.1453 - val_command_2_accuracy: 0.4807 - val_command_2_loss: 0.1640 - val_loss: 0.8368 - val_single_command_accuracy: 0.4857 - val_single_command_loss: 0.0968
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.77243
# 500/500 - 79s - 158ms/step - command_1_accuracy: 0.4938 - command_1_loss: 0.0482 - command_2_accuracy: 0.4939 - command_2_loss: 0.0454 - loss: 0.5977 - single_command_accuracy: 0.4888 - single_command_loss: 0.0757 - val_command_1_accuracy: 0.4804 - val_command_1_loss: 0.1437 - val_command_2_accuracy: 0.4804 - val_command_2_loss: 0.1571 - val_loss: 0.8114 - val_single_command_accuracy: 0.4890 - val_single_command_loss: 0.0861
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.77243
# 500/500 - 79s - 157ms/step - command_1_accuracy: 0.4945 - command_1_loss: 0.0370 - command_2_accuracy: 0.4945 - command_2_loss: 0.0454 - loss: 0.5998 - single_command_accuracy: 0.4872 - single_command_loss: 0.0951 - val_command_1_accuracy: 0.4840 - val_command_1_loss: 0.1207 - val_command_2_accuracy: 0.4817 - val_command_2_loss: 0.1749 - val_loss: 0.8363 - val_single_command_accuracy: 0.4834 - val_single_command_loss: 0.1214
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.77243
# 500/500 - 78s - 157ms/step - command_1_accuracy: 0.4954 - command_1_loss: 0.0339 - command_2_accuracy: 0.4931 - command_2_loss: 0.0491 - loss: 0.6001 - single_command_accuracy: 0.4865 - single_command_loss: 0.1002 - val_command_1_accuracy: 0.4840 - val_command_1_loss: 0.1363 - val_command_2_accuracy: 0.4837 - val_command_2_loss: 0.1544 - val_loss: 0.8105 - val_single_command_accuracy: 0.4874 - val_single_command_loss: 0.1060
# Epoch 67/100
#
# Epoch 67: val_loss improved from 0.77243 to 0.76206, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 67: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 79s - 158ms/step - command_1_accuracy: 0.4939 - command_1_loss: 0.0453 - command_2_accuracy: 0.4949 - command_2_loss: 0.0359 - loss: 0.5707 - single_command_accuracy: 0.4889 - single_command_loss: 0.0782 - val_command_1_accuracy: 0.4864 - val_command_1_loss: 0.1202 - val_command_2_accuracy: 0.4844 - val_command_2_loss: 0.1350 - val_loss: 0.7621 - val_single_command_accuracy: 0.4877 - val_single_command_loss: 0.0988
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.76206
# 500/500 - 80s - 160ms/step - command_1_accuracy: 0.4949 - command_1_loss: 0.0409 - command_2_accuracy: 0.4940 - command_2_loss: 0.0418 - loss: 0.5775 - single_command_accuracy: 0.4870 - single_command_loss: 0.0890 - val_command_1_accuracy: 0.4860 - val_command_1_loss: 0.1123 - val_command_2_accuracy: 0.4817 - val_command_2_loss: 0.1935 - val_loss: 0.8344 - val_single_command_accuracy: 0.4844 - val_single_command_loss: 0.1260
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.76206
# 500/500 - 79s - 158ms/step - command_1_accuracy: 0.4939 - command_1_loss: 0.0429 - command_2_accuracy: 0.4950 - command_2_loss: 0.0376 - loss: 0.5643 - single_command_accuracy: 0.4868 - single_command_loss: 0.0840 - val_command_1_accuracy: 0.4844 - val_command_1_loss: 0.1216 - val_command_2_accuracy: 0.4844 - val_command_2_loss: 0.1696 - val_loss: 0.8108 - val_single_command_accuracy: 0.4860 - val_single_command_loss: 0.1224
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.76206
# 500/500 - 81s - 161ms/step - command_1_accuracy: 0.4943 - command_1_loss: 0.0386 - command_2_accuracy: 0.4952 - command_2_loss: 0.0392 - loss: 0.5500 - single_command_accuracy: 0.4894 - single_command_loss: 0.0772 - val_command_1_accuracy: 0.4844 - val_command_1_loss: 0.1345 - val_command_2_accuracy: 0.4850 - val_command_2_loss: 0.1295 - val_loss: 0.7882 - val_single_command_accuracy: 0.4854 - val_single_command_loss: 0.1328
# Epoch 71/100
#
# Epoch 71: val_loss improved from 0.76206 to 0.74152, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 71: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 80s - 159ms/step - command_1_accuracy: 0.4954 - command_1_loss: 0.0364 - command_2_accuracy: 0.4965 - command_2_loss: 0.0234 - loss: 0.5377 - single_command_accuracy: 0.4874 - single_command_loss: 0.0887 - val_command_1_accuracy: 0.4850 - val_command_1_loss: 0.1166 - val_command_2_accuracy: 0.4820 - val_command_2_loss: 0.1635 - val_loss: 0.7415 - val_single_command_accuracy: 0.4913 - val_single_command_loss: 0.0753
# Epoch 72/100
#
# Epoch 72: val_loss improved from 0.74152 to 0.72813, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 72: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 85s - 170ms/step - command_1_accuracy: 0.4961 - command_1_loss: 0.0301 - command_2_accuracy: 0.4951 - command_2_loss: 0.0361 - loss: 0.5294 - single_command_accuracy: 0.4892 - single_command_loss: 0.0798 - val_command_1_accuracy: 0.4854 - val_command_1_loss: 0.1239 - val_command_2_accuracy: 0.4830 - val_command_2_loss: 0.1408 - val_loss: 0.7281 - val_single_command_accuracy: 0.4877 - val_single_command_loss: 0.0824
# Epoch 73/100
#
# Epoch 73: val_loss improved from 0.72813 to 0.71469, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 73: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 81s - 161ms/step - command_1_accuracy: 0.4952 - command_1_loss: 0.0367 - command_2_accuracy: 0.4954 - command_2_loss: 0.0344 - loss: 0.5338 - single_command_accuracy: 0.4883 - single_command_loss: 0.0841 - val_command_1_accuracy: 0.4854 - val_command_1_loss: 0.1151 - val_command_2_accuracy: 0.4840 - val_command_2_loss: 0.1680 - val_loss: 0.7147 - val_single_command_accuracy: 0.4927 - val_single_command_loss: 0.0553
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.71469
# 500/500 - 80s - 161ms/step - command_1_accuracy: 0.4951 - command_1_loss: 0.0336 - command_2_accuracy: 0.4960 - command_2_loss: 0.0318 - loss: 0.5089 - single_command_accuracy: 0.4902 - single_command_loss: 0.0696 - val_command_1_accuracy: 0.4854 - val_command_1_loss: 0.1195 - val_command_2_accuracy: 0.4820 - val_command_2_loss: 0.1684 - val_loss: 0.7787 - val_single_command_accuracy: 0.4864 - val_single_command_loss: 0.1194
# Epoch 75/100
#
# Epoch 75: val_loss improved from 0.71469 to 0.69787, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 75: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 79s - 157ms/step - command_1_accuracy: 0.4955 - command_1_loss: 0.0299 - command_2_accuracy: 0.4971 - command_2_loss: 0.0242 - loss: 0.4933 - single_command_accuracy: 0.4906 - single_command_loss: 0.0704 - val_command_1_accuracy: 0.4847 - val_command_1_loss: 0.1180 - val_command_2_accuracy: 0.4860 - val_command_2_loss: 0.1359 - val_loss: 0.6979 - val_single_command_accuracy: 0.4887 - val_single_command_loss: 0.0776
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.69787
# 500/500 - 84s - 168ms/step - command_1_accuracy: 0.4964 - command_1_loss: 0.0244 - command_2_accuracy: 0.4963 - command_2_loss: 0.0299 - loss: 0.4941 - single_command_accuracy: 0.4893 - single_command_loss: 0.0754 - val_command_1_accuracy: 0.4867 - val_command_1_loss: 0.1044 - val_command_2_accuracy: 0.4830 - val_command_2_loss: 0.1765 - val_loss: 0.7259 - val_single_command_accuracy: 0.4887 - val_single_command_loss: 0.0826
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.69787
# 500/500 - 78s - 155ms/step - command_1_accuracy: 0.4964 - command_1_loss: 0.0258 - command_2_accuracy: 0.4963 - command_2_loss: 0.0252 - loss: 0.4799 - single_command_accuracy: 0.4902 - single_command_loss: 0.0688 - val_command_1_accuracy: 0.4864 - val_command_1_loss: 0.1202 - val_command_2_accuracy: 0.4837 - val_command_2_loss: 0.1774 - val_loss: 0.7879 - val_single_command_accuracy: 0.4857 - val_single_command_loss: 0.1322
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.69787
# 500/500 - 79s - 157ms/step - command_1_accuracy: 0.4967 - command_1_loss: 0.0245 - command_2_accuracy: 0.4971 - command_2_loss: 0.0238 - loss: 0.4660 - single_command_accuracy: 0.4906 - single_command_loss: 0.0615 - val_command_1_accuracy: 0.4847 - val_command_1_loss: 0.1222 - val_command_2_accuracy: 0.4834 - val_command_2_loss: 0.1616 - val_loss: 0.7063 - val_single_command_accuracy: 0.4907 - val_single_command_loss: 0.0683
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.69787
# 500/500 - 78s - 156ms/step - command_1_accuracy: 0.4969 - command_1_loss: 0.0249 - command_2_accuracy: 0.4978 - command_2_loss: 0.0168 - loss: 0.4630 - single_command_accuracy: 0.4911 - single_command_loss: 0.0689 - val_command_1_accuracy: 0.4857 - val_command_1_loss: 0.1140 - val_command_2_accuracy: 0.4847 - val_command_2_loss: 0.1763 - val_loss: 0.7194 - val_single_command_accuracy: 0.4903 - val_single_command_loss: 0.0787
# Epoch 80/100
#
# Epoch 80: val_loss improved from 0.69787 to 0.69392, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 80: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 80s - 160ms/step - command_1_accuracy: 0.4974 - command_1_loss: 0.0231 - command_2_accuracy: 0.4974 - command_2_loss: 0.0202 - loss: 0.4582 - single_command_accuracy: 0.4909 - single_command_loss: 0.0660 - val_command_1_accuracy: 0.4867 - val_command_1_loss: 0.1147 - val_command_2_accuracy: 0.4840 - val_command_2_loss: 0.1615 - val_loss: 0.6939 - val_single_command_accuracy: 0.4907 - val_single_command_loss: 0.0709
# Epoch 81/100
#
# Epoch 81: val_loss improved from 0.69392 to 0.68687, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 81: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 84s - 168ms/step - command_1_accuracy: 0.4971 - command_1_loss: 0.0236 - command_2_accuracy: 0.4973 - command_2_loss: 0.0176 - loss: 0.4431 - single_command_accuracy: 0.4921 - single_command_loss: 0.0564 - val_command_1_accuracy: 0.4870 - val_command_1_loss: 0.1039 - val_command_2_accuracy: 0.4854 - val_command_2_loss: 0.1497 - val_loss: 0.6869 - val_single_command_accuracy: 0.4877 - val_single_command_loss: 0.0897
# Epoch 82/100
#
# Epoch 82: val_loss improved from 0.68687 to 0.68188, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 82: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 80s - 160ms/step - command_1_accuracy: 0.4971 - command_1_loss: 0.0190 - command_2_accuracy: 0.4976 - command_2_loss: 0.0181 - loss: 0.4321 - single_command_accuracy: 0.4927 - single_command_loss: 0.0526 - val_command_1_accuracy: 0.4860 - val_command_1_loss: 0.1146 - val_command_2_accuracy: 0.4867 - val_command_2_loss: 0.1665 - val_loss: 0.6819 - val_single_command_accuracy: 0.4923 - val_single_command_loss: 0.0602
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.68188
# 500/500 - 83s - 167ms/step - command_1_accuracy: 0.4978 - command_1_loss: 0.0192 - command_2_accuracy: 0.4971 - command_2_loss: 0.0217 - loss: 0.4338 - single_command_accuracy: 0.4925 - single_command_loss: 0.0533 - val_command_1_accuracy: 0.4874 - val_command_1_loss: 0.1122 - val_command_2_accuracy: 0.4860 - val_command_2_loss: 0.1731 - val_loss: 0.7062 - val_single_command_accuracy: 0.4870 - val_single_command_loss: 0.0834
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.68188
# 500/500 - 78s - 155ms/step - command_1_accuracy: 0.4983 - command_1_loss: 0.0128 - command_2_accuracy: 0.4976 - command_2_loss: 0.0166 - loss: 0.4201 - single_command_accuracy: 0.4921 - single_command_loss: 0.0537 - val_command_1_accuracy: 0.4877 - val_command_1_loss: 0.1267 - val_command_2_accuracy: 0.4857 - val_command_2_loss: 0.1732 - val_loss: 0.7168 - val_single_command_accuracy: 0.4913 - val_single_command_loss: 0.0817
# Epoch 85/100
#
# Epoch 85: val_loss improved from 0.68188 to 0.67769, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 85: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 79s - 159ms/step - command_1_accuracy: 0.4979 - command_1_loss: 0.0148 - command_2_accuracy: 0.4972 - command_2_loss: 0.0199 - loss: 0.4203 - single_command_accuracy: 0.4929 - single_command_loss: 0.0508 - val_command_1_accuracy: 0.4874 - val_command_1_loss: 0.1213 - val_command_2_accuracy: 0.4860 - val_command_2_loss: 0.1733 - val_loss: 0.6777 - val_single_command_accuracy: 0.4923 - val_single_command_loss: 0.0501
# Epoch 86/100
#
# Epoch 86: val_loss improved from 0.67769 to 0.65903, saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
#
# Epoch 86: finished saving model to /content/drive/MyDrive/resnet_sequencing/resnet_sequencing.keras
# 500/500 - 81s - 162ms/step - command_1_accuracy: 0.4982 - command_1_loss: 0.0152 - command_2_accuracy: 0.4984 - command_2_loss: 0.0129 - loss: 0.4072 - single_command_accuracy: 0.4929 - single_command_loss: 0.0463 - val_command_1_accuracy: 0.4867 - val_command_1_loss: 0.1139 - val_command_2_accuracy: 0.4867 - val_command_2_loss: 0.1601 - val_loss: 0.6590 - val_single_command_accuracy: 0.4933 - val_single_command_loss: 0.0540
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.65903
# 500/500 - 80s - 161ms/step - command_1_accuracy: 0.4982 - command_1_loss: 0.0113 - command_2_accuracy: 0.4983 - command_2_loss: 0.0137 - loss: 0.4087 - single_command_accuracy: 0.4921 - single_command_loss: 0.0528 - val_command_1_accuracy: 0.4834 - val_command_1_loss: 0.1208 - val_command_2_accuracy: 0.4847 - val_command_2_loss: 0.1691 - val_loss: 0.7214 - val_single_command_accuracy: 0.4857 - val_single_command_loss: 0.1022
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.65903
# 500/500 - 79s - 159ms/step - command_1_accuracy: 0.4982 - command_1_loss: 0.0125 - command_2_accuracy: 0.4972 - command_2_loss: 0.0192 - loss: 0.4082 - single_command_accuracy: 0.4929 - single_command_loss: 0.0472 - val_command_1_accuracy: 0.4864 - val_command_1_loss: 0.1258 - val_command_2_accuracy: 0.4867 - val_command_2_loss: 0.1752 - val_loss: 0.7189 - val_single_command_accuracy: 0.4893 - val_single_command_loss: 0.0898
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.65903
# 500/500 - 79s - 157ms/step - command_1_accuracy: 0.4981 - command_1_loss: 0.0174 - command_2_accuracy: 0.4980 - command_2_loss: 0.0132 - loss: 0.4041 - single_command_accuracy: 0.4931 - single_command_loss: 0.0455 - val_command_1_accuracy: 0.4860 - val_command_1_loss: 0.1212 - val_command_2_accuracy: 0.4867 - val_command_2_loss: 0.1652 - val_loss: 0.6889 - val_single_command_accuracy: 0.4900 - val_single_command_loss: 0.0756
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.65903
# 500/500 - 78s - 156ms/step - command_1_accuracy: 0.4979 - command_1_loss: 0.0186 - command_2_accuracy: 0.4988 - command_2_loss: 0.0115 - loss: 0.4036 - single_command_accuracy: 0.4930 - single_command_loss: 0.0467 - val_command_1_accuracy: 0.4867 - val_command_1_loss: 0.1169 - val_command_2_accuracy: 0.4860 - val_command_2_loss: 0.1785 - val_loss: 0.6995 - val_single_command_accuracy: 0.4920 - val_single_command_loss: 0.0784
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.65903
# 500/500 - 79s - 158ms/step - command_1_accuracy: 0.4987 - command_1_loss: 0.0092 - command_2_accuracy: 0.4979 - command_2_loss: 0.0136 - loss: 0.3945 - single_command_accuracy: 0.4931 - single_command_loss: 0.0460 - val_command_1_accuracy: 0.4867 - val_command_1_loss: 0.1098 - val_command_2_accuracy: 0.4864 - val_command_2_loss: 0.1719 - val_loss: 0.6774 - val_single_command_accuracy: 0.4917 - val_single_command_loss: 0.0709
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.65903
# 500/500 - 78s - 156ms/step - command_1_accuracy: 0.4979 - command_1_loss: 0.0141 - command_2_accuracy: 0.4990 - command_2_loss: 0.0092 - loss: 0.3940 - single_command_accuracy: 0.4934 - single_command_loss: 0.0457 - val_command_1_accuracy: 0.4864 - val_command_1_loss: 0.1155 - val_command_2_accuracy: 0.4860 - val_command_2_loss: 0.1712 - val_loss: 0.6739 - val_single_command_accuracy: 0.4923 - val_single_command_loss: 0.0632
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.65903
# 500/500 - 78s - 157ms/step - command_1_accuracy: 0.4986 - command_1_loss: 0.0126 - command_2_accuracy: 0.4988 - command_2_loss: 0.0095 - loss: 0.3933 - single_command_accuracy: 0.4935 - single_command_loss: 0.0470 - val_command_1_accuracy: 0.4870 - val_command_1_loss: 0.1158 - val_command_2_accuracy: 0.4860 - val_command_2_loss: 0.1728 - val_loss: 0.6826 - val_single_command_accuracy: 0.4910 - val_single_command_loss: 0.0703
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.65903
# 500/500 - 79s - 159ms/step - command_1_accuracy: 0.4988 - command_1_loss: 0.0091 - command_2_accuracy: 0.4979 - command_2_loss: 0.0144 - loss: 0.3926 - single_command_accuracy: 0.4937 - single_command_loss: 0.0455 - val_command_1_accuracy: 0.4874 - val_command_1_loss: 0.1191 - val_command_2_accuracy: 0.4860 - val_command_2_loss: 0.1727 - val_loss: 0.7173 - val_single_command_accuracy: 0.4903 - val_single_command_loss: 0.1024
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.65903
# 500/500 - 76s - 153ms/step - command_1_accuracy: 0.4984 - command_1_loss: 0.0104 - command_2_accuracy: 0.4989 - command_2_loss: 0.0077 - loss: 0.3804 - single_command_accuracy: 0.4945 - single_command_loss: 0.0392 - val_command_1_accuracy: 0.4864 - val_command_1_loss: 0.1237 - val_command_2_accuracy: 0.4860 - val_command_2_loss: 0.1722 - val_loss: 0.6905 - val_single_command_accuracy: 0.4900 - val_single_command_loss: 0.0724
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.65903
# 500/500 - 78s - 156ms/step - command_1_accuracy: 0.4983 - command_1_loss: 0.0114 - command_2_accuracy: 0.4981 - command_2_loss: 0.0142 - loss: 0.3846 - single_command_accuracy: 0.4942 - single_command_loss: 0.0361 - val_command_1_accuracy: 0.4867 - val_command_1_loss: 0.1217 - val_command_2_accuracy: 0.4864 - val_command_2_loss: 0.1709 - val_loss: 0.6910 - val_single_command_accuracy: 0.4913 - val_single_command_loss: 0.0760
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.65903
# 500/500 - 78s - 156ms/step - command_1_accuracy: 0.4989 - command_1_loss: 0.0105 - command_2_accuracy: 0.4981 - command_2_loss: 0.0123 - loss: 0.3824 - single_command_accuracy: 0.4946 - single_command_loss: 0.0370 - val_command_1_accuracy: 0.4867 - val_command_1_loss: 0.1206 - val_command_2_accuracy: 0.4864 - val_command_2_loss: 0.1712 - val_loss: 0.6900 - val_single_command_accuracy: 0.4907 - val_single_command_loss: 0.0762
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.65903
# 500/500 - 79s - 158ms/step - command_1_accuracy: 0.4988 - command_1_loss: 0.0128 - command_2_accuracy: 0.4991 - command_2_loss: 0.0080 - loss: 0.3740 - single_command_accuracy: 0.4958 - single_command_loss: 0.0307 - val_command_1_accuracy: 0.4870 - val_command_1_loss: 0.1205 - val_command_2_accuracy: 0.4864 - val_command_2_loss: 0.1710 - val_loss: 0.7201 - val_single_command_accuracy: 0.4883 - val_single_command_loss: 0.1064
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.65903
# 500/500 - 78s - 156ms/step - command_1_accuracy: 0.4981 - command_1_loss: 0.0121 - command_2_accuracy: 0.4980 - command_2_loss: 0.0133 - loss: 0.3856 - single_command_accuracy: 0.4945 - single_command_loss: 0.0378 - val_command_1_accuracy: 0.4867 - val_command_1_loss: 0.1204 - val_command_2_accuracy: 0.4864 - val_command_2_loss: 0.1717 - val_loss: 0.7357 - val_single_command_accuracy: 0.4880 - val_single_command_loss: 0.1216
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.65903
# 500/500 - 78s - 157ms/step - command_1_accuracy: 0.4978 - command_1_loss: 0.0152 - command_2_accuracy: 0.4978 - command_2_loss: 0.0143 - loss: 0.3924 - single_command_accuracy: 0.4943 - single_command_loss: 0.0405 - val_command_1_accuracy: 0.4867 - val_command_1_loss: 0.1201 - val_command_2_accuracy: 0.4864 - val_command_2_loss: 0.1710 - val_loss: 0.6860 - val_single_command_accuracy: 0.4910 - val_single_command_loss: 0.0729
# Restoring model weights from the end of the best epoch: 86.
# Finished training

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(history.history['single_command_accuracy'],     'b-',  label='Single (train)', linewidth=2)
axes[0].plot(history.history['val_single_command_accuracy'], 'b--', label='Single (val)',   linewidth=2)
axes[0].plot(history.history['command_1_accuracy'],          'r-',  label='Cmd1 (train)',   linewidth=2)
axes[0].plot(history.history['val_command_1_accuracy'],      'r--', label='Cmd1 (val)',     linewidth=2)
axes[0].plot(history.history['command_2_accuracy'],          'g-',  label='Cmd2 (train)',   linewidth=2)
axes[0].plot(history.history['val_command_2_accuracy'],      'g--', label='Cmd2 (val)',     linewidth=2)
axes[0].set_title('Accuracy per Head', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend(loc='lower right')
axes[0].grid(True, alpha=0.3)

axes[1].plot(history.history['loss'],     'b-', label='Train loss', linewidth=2)
axes[1].plot(history.history['val_loss'], 'r-', label='Val loss',   linewidth=2)
axes[1].set_title('Total Loss', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend(loc='upper right')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

best_val_acc = max(history.history['val_single_command_accuracy'])
best_epoch   = np.argmax(history.history['val_single_command_accuracy']) + 1
print("TRAINING SUMMARY")
print(f"  Total epochs:            {len(history.history['loss'])}")
print(f"  Best single cmd val acc: {best_val_acc:.4f} (epoch {best_epoch})")
print(f"  Best cmd1 val acc:       {max(history.history['val_command_1_accuracy']):.4f}")
print(f"  Best cmd2 val acc:       {max(history.history['val_command_2_accuracy']):.4f}")
gap = history.history['single_command_accuracy'][-1] - \
      history.history['val_single_command_accuracy'][-1]
print(f"  Train/val gap:           {gap:+.4f}")
# Out:
# TRAINING SUMMARY
#   Total epochs:            100
#   Best single cmd val acc: 0.4933 (epoch 86)
#   Best cmd1 val acc:       0.4877
#   Best cmd2 val acc:       0.4867
#   Train/val gap:           +0.0033

# %%
custom_objects = {
    'CosineDecayWithWarmup':      CosineDecayWithWarmup,
    'masked_sparse_crossentropy': masked_sparse_crossentropy
}
best_model = keras.models.load_model(
    f'{DRIVE_DIR}/{MODEL_NAME}.keras',
    custom_objects=custom_objects
)

# ── Single command evaluation ──────────────────────────────────
print("Building single-command test spectrograms...")
X_test_specs = np.array([extract_mel_spectrogram(a) for a in X_raw_test])
X_test_specs = (X_test_specs - X_mean) / X_std
X_test_specs = X_test_specs[..., np.newaxis]

y_pred_all    = best_model.predict(X_test_specs, verbose=0)
y_pred_single = np.argmax(y_pred_all[0], axis=1)
single_acc    = np.mean(y_pred_single == y_test)

# ── Sequential evaluation ──────────────────────────────────────
print("Building sequential test spectrograms...")
X_seq_test_specs = np.array([extract_mel_spectrogram(a) for a in X_seq_test])
X_seq_test_specs = (X_seq_test_specs - X_seq_mean) / X_seq_std
X_seq_test_specs = X_seq_test_specs[..., np.newaxis]

y_pred_seq   = best_model.predict(X_seq_test_specs, verbose=0)
y_pred_cmd1  = np.argmax(y_pred_seq[1], axis=1)
y_pred_cmd2  = np.argmax(y_pred_seq[2], axis=1)
acc_cmd1     = np.mean(y_pred_cmd1 == y_seq_test[:, 0])
acc_cmd2     = np.mean(y_pred_cmd2 == y_seq_test[:, 1])
both_correct = np.mean(
    (y_pred_cmd1 == y_seq_test[:, 0]) &
    (y_pred_cmd2 == y_seq_test[:, 1])
)
test_accuracy = single_acc

print("\n" + "=" * 60)
print("TEST RESULTS")
print("=" * 60)
print(f"  Single command accuracy:     {single_acc:.4f} ({single_acc*100:.2f}%)")
print(f"  Sequential cmd1 accuracy:    {acc_cmd1:.4f} ({acc_cmd1*100:.2f}%)")
print(f"  Sequential cmd2 accuracy:    {acc_cmd2:.4f} ({acc_cmd2*100:.2f}%)")
print(f"  Full sequence accuracy:      {both_correct:.4f} ({both_correct*100:.2f}%)")
print("=" * 60)

print("\nSingle Command - Classification Report:")
print(classification_report(y_test, y_pred_single,
                             target_names=label_encoder.classes_, digits=4))
print("\nSequential Cmd1 - Classification Report:")
print(classification_report(y_seq_test[:, 0], y_pred_cmd1,
                             target_names=label_encoder.classes_, digits=4))
print("\nSequential Cmd2 - Classification Report:")
print(classification_report(y_seq_test[:, 1], y_pred_cmd2,
                             target_names=label_encoder.classes_, digits=4))
# Out:
# Building single-command test spectrograms...
# Building sequential test spectrograms...
#
# ============================================================
# TEST RESULTS
# ============================================================
#   Single command accuracy:     0.9141 (91.41%)
#   Sequential cmd1 accuracy:    0.9827 (98.27%)
#   Sequential cmd2 accuracy:    0.9720 (97.20%)
#   Full sequence accuracy:      0.9547 (95.47%)
# ============================================================
#
# Single Command - Classification Report:
#                     precision    recall  f1-score   support
#
# _background_noise_     0.8235    0.0622    0.1157       225
#               down     0.9433    0.9642    0.9537       587
#                 go     0.9583    0.9485    0.9534       582
#               left     0.9961    0.8982    0.9446       570
#                 no     0.9961    0.8596    0.9228       591
#                off     0.9147    0.9537    0.9338       562
#                 on     0.8652    0.9792    0.9187       577
#              right     0.7322    0.9788    0.8377       567
#               stop     0.9644    0.9793    0.9718       581
#                 up     0.8741    0.9211    0.8970       558
#                yes     0.9756    0.9885    0.9820       607
#
#           accuracy                         0.9141      6007
#          macro avg     0.9131    0.8667    0.8574      6007
#       weighted avg     0.9193    0.9141    0.9016      6007
#
#
# Sequential Cmd1 - Classification Report:
#                     precision    recall  f1-score   support
#
# _background_noise_     1.0000    1.0000    1.0000        46
#               down     0.9935    0.9684    0.9808       158
#                 go     0.9843    0.9766    0.9804       128
#               left     0.9796    0.9931    0.9863       145
#                 no     0.9685    0.9919    0.9801       124
#                off     0.9706    0.9851    0.9778       134
#                 on     0.9728    0.9931    0.9828       144
#              right     1.0000    0.9745    0.9871       157
#               stop     1.0000    0.9704    0.9850       169
#                 up     0.9548    0.9867    0.9705       150
#                yes     0.9931    0.9862    0.9896       145
#
#           accuracy                         0.9827      1500
#          macro avg     0.9834    0.9842    0.9837      1500
#       weighted avg     0.9830    0.9827    0.9827      1500
#
#
# Sequential Cmd2 - Classification Report:
#                     precision    recall  f1-score   support
#
# _background_noise_     1.0000    1.0000    1.0000        50
#               down     0.9806    0.9744    0.9775       156
#                 go     0.9524    0.9655    0.9589       145
#               left     0.9857    0.9650    0.9753       143
#                 no     0.9677    0.9868    0.9772       152
#                off     0.9441    0.9507    0.9474       142
#                 on     0.9600    1.0000    0.9796       144
#              right     1.0000    0.9563    0.9776       160
#               stop     0.9779    1.0000    0.9888       133
#                 up     0.9407    0.9203    0.9304       138
#                yes     1.0000    0.9927    0.9963       137
#
#           accuracy                         0.9720      1500
#          macro avg     0.9736    0.9738    0.9735      1500
#       weighted avg     0.9722    0.9720    0.9720      1500

# %%
fig, axes = plt.subplots(1, 3, figsize=(32, 9))

for ax, y_true, y_pred_labels, title in [
    (axes[0], y_test,           y_pred_single, 'Single Command'),
    (axes[1], y_seq_test[:, 0], y_pred_cmd1,   'Sequential — Command 1'),
    (axes[2], y_seq_test[:, 1], y_pred_cmd2,   'Sequential — Command 2'),
]:
    cm = confusion_matrix(y_true, y_pred_labels)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=label_encoder.classes_,
                yticklabels=label_encoder.classes_, ax=ax)
    ax.set_title(title, fontsize=13, fontweight='bold')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')
    ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

print("Per-Class Accuracy (Single Command Head):")
print("-" * 40)
cm_single      = confusion_matrix(y_test, y_pred_single)
class_accuracy = cm_single.diagonal() / cm_single.sum(axis=1)
for name, acc in sorted(zip(label_encoder.classes_, class_accuracy), key=lambda x: -x[1]):
    bar = '█' * int(acc * 30)
    print(f"  {name:20s}: {acc:.4f} {bar}")
# Out:
# Per-Class Accuracy (Single Command Head):
# ----------------------------------------
#   yes                 : 0.9885 █████████████████████████████
#   stop                : 0.9793 █████████████████████████████
#   on                  : 0.9792 █████████████████████████████
#   right               : 0.9788 █████████████████████████████
#   down                : 0.9642 ████████████████████████████
#   off                 : 0.9537 ████████████████████████████
#   go                  : 0.9485 ████████████████████████████
#   up                  : 0.9211 ███████████████████████████
#   left                : 0.8982 ██████████████████████████
#   no                  : 0.8596 █████████████████████████
#   _background_noise_  : 0.0622 █

# %%
import json, pickle

print("=" * 60)
print("SAVING MODEL AND ARTIFACTS")
print("=" * 60)

model.save(f'{MODEL_NAME}_final.keras')

with open('label_encoder.pkl', 'wb') as f:
    pickle.dump(label_encoder, f)

config = {
    'model_name':          MODEL_NAME,
    'commands':            list(label_encoder.classes_),
    'num_classes':         num_classes,
    'sample_rate':         SAMPLE_RATE,
    'audio_length':        AUDIO_LENGTH,
    'n_mels':              N_MELS,
    'n_fft':               N_FFT,
    'hop_length':          HOP_LENGTH,
    'single_mean':         float(X_mean),
    'single_std':          float(X_std),
    'seq_mean':            float(X_seq_mean),
    'seq_std':             float(X_seq_std),
    'noise_augmentation':  True,
    'noise_prob':          NOISE_AUGMENT_PROB,
    'noise_snr_db':        NOISE_SNR_DB,
    'noise_class_samples': len(noise_samples),
    'max_output_len':      MAX_OUTPUT_LEN,
    'single_test_acc':     float(single_acc),
    'seq_cmd1_acc':        float(acc_cmd1),
    'seq_cmd2_acc':        float(acc_cmd2),
    'seq_both_acc':        float(both_correct),
    'best_val_acc':        float(best_val_acc),
    'training_epochs':     len(history.history['loss'])
}

with open('model_config.json', 'w') as f:
    json.dump(config, f, indent=2)

print(f"✓ Final model saved: {MODEL_NAME}_final.keras")
print("✓ Label encoder saved: label_encoder.pkl")
print("✓ Config saved: model_config.json")
print(json.dumps(config, indent=2))
# Out:
# ============================================================
# SAVING MODEL AND ARTIFACTS
# ============================================================
# ✓ Final model saved: resnet_sequencing_final.keras
# ✓ Label encoder saved: label_encoder.pkl
# ✓ Config saved: model_config.json
# {
#   "model_name": "resnet_sequencing",
#   "commands": [
#     "_background_noise_",
#     "down",
#     "go",
#     "left",
#     "no",
#     "off",
#     "on",
#     "right",
#     "stop",
#     "up",
#     "yes"
#   ],
#   "num_classes": 11,
#   "sample_rate": 16000,
#   "audio_length": 16000,
#   "n_mels": 128,
#   "n_fft": 2048,
#   "hop_length": 160,
#   "single_mean": -56.730995178222656,
#   "single_std": 20.285085678100586,
#   "seq_mean": -61.67680706851633,
#   "seq_std": 19.54796869734301,
#   "noise_augmentation": true,
#   "noise_prob": 0.4,
#   "noise_snr_db": 10,
#   "noise_class_samples": 1500,
#   "max_output_len": 2,
#   "single_test_acc": 0.9141002164141835,
#   "seq_cmd1_acc": 0.9826666666666667,
#   "seq_cmd2_acc": 0.972,
#   "seq_both_acc": 0.9546666666666667,
#   "best_val_acc": 0.49334222078323364,
#   "training_epochs": 100
# }

# %%
files_to_copy = [
    f'{MODEL_NAME}_final.keras',
    'label_encoder.pkl',
    'model_config.json',
    'training_log.csv'
]

print(f"Copying files to: {DRIVE_DIR}")
for f in files_to_copy:
    if os.path.exists(f):
        shutil.copy(f, os.path.join(DRIVE_DIR, f))
        print(f"  ✓ {f}")
    else:
        print(f"  ⚠️  {f} not found")

print(f"\n✓ Drive folder contains:")
print(f"  • {MODEL_NAME}.keras          ← best checkpoint (saved during training)")
print(f"  • {MODEL_NAME}_final.keras    ← final epoch")
print(f"  • label_encoder.pkl")
print(f"  • model_config.json")
print(f"  • training_log.csv")
# Out:
# Copying files to: /content/drive/MyDrive/resnet_sequencing
#   ✓ resnet_sequencing_final.keras
#   ✓ label_encoder.pkl
#   ✓ model_config.json
#   ✓ training_log.csv
#
# ✓ Drive folder contains:
#   • resnet_sequencing.keras          ← best checkpoint (saved during training)
#   • resnet_sequencing_final.keras    ← final epoch
#   • label_encoder.pkl
#   • model_config.json
#   • training_log.csv

# %%
utils_code = '''
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import register_keras_serializable

@register_keras_serializable(package="CustomSchedules")
class CosineDecayWithWarmup(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, initial_learning_rate=1e-3, decay_steps=10000,
                 warmup_steps=1000, min_learning_rate=1e-6):
        super().__init__()
        self.initial_learning_rate = initial_learning_rate
        self.decay_steps           = decay_steps
        self.warmup_steps          = warmup_steps
        self.min_learning_rate     = min_learning_rate

    def __call__(self, step):
        step     = tf.cast(step, tf.float32)
        warmup_f = tf.cast(self.warmup_steps, tf.float32)
        decay_f  = tf.cast(self.decay_steps,  tf.float32)
        warmup_lr   = self.initial_learning_rate * (step / tf.maximum(warmup_f, 1.0))
        decay_step  = step - warmup_f
        total_decay = tf.maximum(decay_f - warmup_f, 1.0)
        cosine      = 0.5 * (1.0 + tf.cos(np.pi * decay_step / total_decay))
        decayed_lr  = self.min_learning_rate + \
                      (self.initial_learning_rate - self.min_learning_rate) * cosine
        return tf.where(step < warmup_f, warmup_lr, decayed_lr)

    def get_config(self):
        return {
            'initial_learning_rate': float(self.initial_learning_rate),
            'decay_steps':           int(self.decay_steps),
            'warmup_steps':          int(self.warmup_steps),
            'min_learning_rate':     float(self.min_learning_rate)
        }

    @classmethod
    def from_config(cls, config):
        return cls(**config)


def masked_sparse_crossentropy(y_true, y_pred):
    import tensorflow as tf
    from tensorflow import keras
    mask   = tf.cast(tf.not_equal(y_true, -1), tf.float32)
    y_true = tf.maximum(y_true, 0)
    loss   = keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
    return tf.reduce_sum(loss * mask) / (tf.reduce_sum(mask) + 1e-8)
'''

with open(os.path.join(DRIVE_DIR, 'utils.py'), 'w') as f:
    f.write(utils_code)
print("✓ utils.py saved to Drive")
print(f"\nTo load the model anywhere:")
print(f"  from utils import CosineDecayWithWarmup, masked_sparse_crossentropy")
print(f"  from tensorflow import keras")
print(f"  model = keras.models.load_model('{MODEL_NAME}.keras',")
print(f"    custom_objects={{")
print(f"      'CosineDecayWithWarmup': CosineDecayWithWarmup,")
print(f"      'masked_sparse_crossentropy': masked_sparse_crossentropy")
print(f"    }})")
# Out:
# ✓ utils.py saved to Drive
#
# To load the model anywhere:
#   from utils import CosineDecayWithWarmup, masked_sparse_crossentropy
#   from tensorflow import keras
#   model = keras.models.load_model('resnet_sequencing.keras',
#     custom_objects={
#       'CosineDecayWithWarmup': CosineDecayWithWarmup,
#       'masked_sparse_crossentropy': masked_sparse_crossentropy
#     })
